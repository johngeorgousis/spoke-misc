# %% [markdown]
# ## 🟥 Imports

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# absl-py                            1.4.0
# accelerate                         0.34.2
# aiohappyeyeballs                   2.4.3
# aiohttp                            3.10.10
# aiosignal                          1.3.1
# alabaster                          0.7.16
# albucore                           0.0.19
# albumentations                     1.4.20
# altair                             4.2.2
# annotated-types                    0.7.0
# anyio                              3.7.1
# argon2-cffi                        23.1.0
# argon2-cffi-bindings               21.2.0
# array_record                       0.5.1
# arviz                              0.20.0
# astropy                            6.1.4
# astropy-iers-data                  0.2024.10.28.0.34.7
# astunparse                         1.6.3
# async-timeout                      4.0.3
# atpublic                           4.1.0
# attrs                              24.2.0
# audioread                          3.0.1
# autograd                           1.7.0
# babel                              2.16.0
# backcall                           0.2.0
# beautifulsoup4                     4.12.3
# bigframes                          1.25.0
# bigquery-magics                    0.4.0
# bleach                             6.2.0
# blinker                            1.4
# blis                               0.7.11
# blosc2                             2.0.0
# bokeh                              3.4.3
# Bottleneck                         1.4.2
# bqplot                             0.12.43
# branca                             0.8.0
# CacheControl                       0.14.0
# cachetools                         5.5.0
# catalogue                          2.0.10
# certifi                            2024.8.30
# cffi                               1.17.1
# chardet                            5.2.0
# charset-normalizer                 3.4.0
# chex                               0.1.87
# clarabel                           0.9.0
# click                              8.1.7
# cloudpathlib                       0.20.0
# cloudpickle                        3.1.0
# cmake                              3.30.5
# cmdstanpy                          1.2.4
# colorcet                           3.1.0
# colorlover                         0.3.0
# colour                             0.1.5
# community                          1.0.0b1
# confection                         0.1.5
# cons                               0.4.6
# contourpy                          1.3.0
# cryptography                       43.0.3
# cuda-python                        12.2.1
# cudf-cu12                          24.10.1
# cufflinks                          0.17.3
# cupy-cuda12x                       12.2.0
# cvxopt                             1.3.2
# cvxpy                              1.5.3
# cycler                             0.12.1
# cymem                              2.0.8
# Cython                             3.0.11
# dask                               2024.10.0
# datascience                        0.17.6
# db-dtypes                          1.3.0
# dbus-python                        1.2.18
# debugpy                            1.6.6
# decorator                          4.4.2
# defusedxml                         0.7.1
# Deprecated                         1.2.14
# diffusers                          0.30.3
# distro                             1.9.0
# dlib                               19.24.2
# dm-tree                            0.1.8
# docker-pycreds                     0.4.0
# docstring_parser                   0.16
# docutils                           0.18.1
# dopamine_rl                        4.0.9
# duckdb                             1.1.2
# earthengine-api                    1.2.0
# easydict                           1.13
# ecos                               2.0.14
# editdistance                       0.8.1
# eerepr                             0.0.4
# einops                             0.8.0
# en-core-web-sm                     3.7.1
# entrypoints                        0.4
# et_xmlfile                         2.0.0
# etils                              1.10.0
# etuples                            0.3.9
# eval_type_backport                 0.2.0
# exceptiongroup                     1.2.2
# fastai                             2.7.18
# fastcore                           1.7.19
# fastdownload                       0.0.7
# fastjsonschema                     2.20.0
# fastprogress                       1.0.3
# fastrlock                          0.8.2
# filelock                           3.16.1
# firebase-admin                     6.5.0
# Flask                              2.2.5
# flatbuffers                        24.3.25
# flax                               0.8.5
# folium                             0.18.0
# fonttools                          4.54.1
# frozendict                         2.4.6
# frozenlist                         1.5.0
# fsspec                             2024.10.0
# future                             1.0.0
# gast                               0.6.0
# gcsfs                              2024.10.0
# GDAL                               3.6.4
# gdown                              5.2.0
# geemap                             0.35.0
# gensim                             4.3.3
# geocoder                           1.38.1
# geographiclib                      2.0
# geopandas                          1.0.1
# geopy                              2.4.1
# gin-config                         0.5.0
# gitdb                              4.0.11
# GitPython                          3.1.43
# glob2                              0.7
# google                             2.0.3
# google-ai-generativelanguage       0.6.10
# google-api-core                    2.19.2
# google-api-python-client           2.137.0
# google-auth                        2.27.0
# google-auth-httplib2               0.2.0
# google-auth-oauthlib               1.2.1
# google-cloud-aiplatform            1.70.0
# google-cloud-bigquery              3.25.0
# google-cloud-bigquery-connection   1.15.5
# google-cloud-bigquery-storage      2.27.0
# google-cloud-bigtable              2.26.0
# google-cloud-core                  2.4.1
# google-cloud-datastore             2.19.0
# google-cloud-firestore             2.16.1
# google-cloud-functions             1.16.5
# google-cloud-iam                   2.16.0
# google-cloud-language              2.13.4
# google-cloud-pubsub                2.25.0
# google-cloud-resource-manager      1.13.0
# google-cloud-storage               2.8.0
# google-cloud-translate             3.15.5
# google-colab                       1.0.0
# google-crc32c                      1.6.0
# google-generativeai                0.8.3
# google-pasta                       0.2.0
# google-resumable-media             2.7.2
# googleapis-common-protos           1.65.0
# googledrivedownloader              0.4
# graphviz                           0.20.3
# greenlet                           3.1.1
# grpc-google-iam-v1                 0.13.1
# grpcio                             1.64.1
# grpcio-status                      1.48.2
# gspread                            6.0.2
# gspread-dataframe                  3.3.1
# gym                                0.25.2
# gym-notices                        0.0.8
# h11                                0.14.0
# h5netcdf                           1.4.0
# h5py                               3.12.1
# holidays                           0.59
# holoviews                          1.19.1
# html5lib                           1.1
# httpcore                           1.0.6
# httpimport                         1.4.0
# httplib2                           0.22.0
# httpx                              0.27.2
# huggingface-hub                    0.24.7
# humanize                           4.11.0
# hyperopt                           0.2.7
# ibis-framework                     9.2.0
# idna                               3.10
# imageio                            2.36.0
# imageio-ffmpeg                     0.5.1
# imagesize                          1.4.1
# imbalanced-learn                   0.12.4
# imgaug                             0.4.0
# immutabledict                      4.2.0
# importlib_metadata                 8.5.0
# importlib_resources                6.4.5
# imutils                            0.5.4
# inflect                            7.4.0
# iniconfig                          2.0.0
# intel-cmplr-lib-ur                 2025.0.0
# intel-openmp                       2025.0.0
# ipyevents                          2.0.2
# ipyfilechooser                     0.6.0
# ipykernel                          5.5.6
# ipyleaflet                         0.19.2
# ipyparallel                        8.8.0
# ipython                            7.34.0
# ipython-genutils                   0.2.0
# ipython-sql                        0.5.0
# ipytree                            0.2.2
# ipywidgets                         7.7.1
# itsdangerous                       2.2.0
# jax                                0.4.33
# jax-cuda12-pjrt                    0.4.33
# jax-cuda12-plugin                  0.4.33
# jaxlib                             0.4.33
# jeepney                            0.7.1
# jellyfish                          1.1.0
# jieba                              0.42.1
# Jinja2                             3.1.4
# jiter                              0.6.1
# joblib                             1.4.2
# jsonpatch                          1.33
# jsonpickle                         3.3.0
# jsonpointer                        3.0.0
# jsonschema                         4.23.0
# jsonschema-specifications          2024.10.1
# jupyter-client                     6.1.12
# jupyter-console                    6.1.0
# jupyter_core                       5.7.2
# jupyter-leaflet                    0.19.2
# jupyter-server                     1.24.0
# jupyterlab_pygments                0.3.0
# jupyterlab_widgets                 3.0.13
# kaggle                             1.6.17
# kagglehub                          0.3.3
# keras                              3.4.1
# keyring                            23.5.0
# kiwisolver                         1.4.7
# langchain                          0.3.4
# langchain-core                     0.3.13
# langchain-text-splitters           0.3.0
# langcodes                          3.4.1
# langsmith                          0.1.137
# language_data                      1.2.0
# launchpadlib                       1.10.16
# lazr.restfulclient                 0.14.4
# lazr.uri                           1.0.6
# lazy_loader                        0.4
# libclang                           18.1.1
# libcudf-cu12                       24.10.1
# librosa                            0.10.2.post1
# lightgbm                           4.5.0
# linkify-it-py                      2.0.3
# llvmlite                           0.43.0
# locket                             1.0.0
# logical-unification                0.4.6
# lxml                               5.3.0
# marisa-trie                        1.2.1
# Markdown                           3.7
# markdown-it-py                     3.0.0
# MarkupSafe                         3.0.2
# matplotlib                         3.8.0
# matplotlib-inline                  0.1.7
# matplotlib-venn                    1.1.1
# mdit-py-plugins                    0.4.2
# mdurl                              0.1.2
# miniKanren                         1.0.3
# missingno                          0.5.2
# mistune                            3.0.2
# mizani                             0.13.0
# mkl                                2024.2.2
# ml-dtypes                          0.4.1
# mlxtend                            0.23.1
# more-itertools                     10.5.0
# moviepy                            1.0.3
# mpmath                             1.3.0
# msgpack                            1.1.0
# multidict                          6.1.0
# multipledispatch                   1.0.0
# multitasking                       0.0.11
# murmurhash                         1.0.10
# music21                            9.1.0
# namex                              0.0.8
# natsort                            8.4.0
# nbclassic                          1.1.0
# nbclient                           0.10.0
# nbconvert                          7.16.4
# nbformat                           5.10.4
# nest-asyncio                       1.6.0
# networkx                           3.4.2
# nibabel                            5.3.2
# nltk                               3.8.1
# notebook                           6.5.5
# notebook_shim                      0.2.4
# numba                              0.60.0
# numexpr                            2.10.1
# numpy                              1.26.4
# nvidia-cublas-cu12                 12.6.3.3
# nvidia-cuda-cupti-cu12             12.6.80
# nvidia-cuda-nvcc-cu12              12.6.77
# nvidia-cuda-runtime-cu12           12.6.77
# nvidia-cudnn-cu12                  9.5.1.17
# nvidia-cufft-cu12                  11.3.0.4
# nvidia-curand-cu12                 10.3.7.77
# nvidia-cusolver-cu12               11.7.1.2
# nvidia-cusparse-cu12               12.5.4.2
# nvidia-nccl-cu12                   2.23.4
# nvidia-nvjitlink-cu12              12.6.77
# nvtx                               0.2.10
# nx-cugraph-cu12                    24.10.0
# oauth2client                       4.1.3
# oauthlib                           3.2.2
# openai                             1.52.2
# opencv-contrib-python              4.10.0.84
# opencv-python                      4.10.0.84
# opencv-python-headless             4.10.0.84
# openpyxl                           3.1.5
# opentelemetry-api                  1.16.0
# opentelemetry-sdk                  1.16.0
# opentelemetry-semantic-conventions 0.37b0
# opt_einsum                         3.4.0
# optax                              0.2.3
# optree                             0.13.0
# orbax-checkpoint                   0.6.4
# orjson                             3.10.10
# osqp                               0.6.7.post3
# packaging                          24.1
# pandas                             2.2.2
# pandas-datareader                  0.10.0
# pandas-gbq                         0.24.0
# pandas-stubs                       2.2.2.240909
# pandocfilters                      1.5.1
# panel                              1.4.5
# param                              2.1.1
# parso                              0.8.4
# parsy                              2.1
# partd                              1.4.2
# pathlib                            1.0.1
# patsy                              0.5.6
# peewee                             3.17.7
# peft                               0.13.2
# pexpect                            4.9.0
# pickleshare                        0.7.5
# pillow                             10.4.0
# pip                                24.1.2
# platformdirs                       4.3.6
# plotly                             5.24.1
# plotnine                           0.14.0
# pluggy                             1.5.0
# polars                             1.9.0
# pooch                              1.8.2
# portpicker                         1.5.2
# preshed                            3.0.9
# prettytable                        3.11.0
# proglog                            0.1.10
# progressbar2                       4.5.0
# prometheus_client                  0.21.0
# promise                            2.3
# prompt_toolkit                     3.0.48
# propcache                          0.2.0
# prophet                            1.1.6
# proto-plus                         1.25.0
# protobuf                           3.20.3
# psutil                             5.9.5
# psycopg2                           2.9.10
# ptyprocess                         0.7.0
# py-cpuinfo                         9.0.0
# py4j                               0.10.9.7
# pyarrow                            17.0.0
# pyarrow-hotfix                     0.6
# pyasn1                             0.6.1
# pyasn1_modules                     0.4.1
# pycocotools                        2.0.8
# pycparser                          2.22
# pydantic                           2.9.2
# pydantic_core                      2.23.4
# pydata-google-auth                 1.8.2
# pydot                              3.0.2
# pydotplus                          2.0.2
# PyDrive                            1.3.1
# PyDrive2                           1.20.0
# pyerfa                             2.0.1.4
# pygame                             2.6.1
# pygit2                             1.16.0
# Pygments                           2.18.0
# PyGObject                          3.42.1
# PyJWT                              2.9.0
# pylibcudf-cu12                     24.10.1
# pylibcugraph-cu12                  24.10.0
# pylibraft-cu12                     24.10.0
# pymc                               5.17.0
# pymystem3                          0.2.0
# pynvjitlink-cu12                   0.4.0
# pyogrio                            0.10.0
# PyOpenGL                           3.1.7
# pyOpenSSL                          24.2.1
# pyparsing                          3.2.0
# pyperclip                          1.9.0
# pyproj                             3.7.0
# pyshp                              2.3.1
# PySocks                            1.7.1
# pyspark                            3.5.3
# pytensor                           2.25.5
# pytest                             7.4.4
# python-apt                         0.0.0
# python-box                         7.2.0
# python-dateutil                    2.8.2
# python-louvain                     0.16
# python-slugify                     8.0.4
# python-utils                       3.9.0
# pytz                               2024.2
# pyviz_comms                        3.0.3
# PyYAML                             6.0.2
# pyzmq                              24.0.1
# qdldl                              0.1.7.post4
# ratelim                            0.1.6
# referencing                        0.35.1
# regex                              2024.9.11
# requests                           2.32.3
# requests-oauthlib                  1.3.1
# requests-toolbelt                  1.0.0
# requirements-parser                0.9.0
# rich                               13.9.3
# rmm-cu12                           24.10.0
# rpds-py                            0.20.0
# rpy2                               3.4.2
# rsa                                4.9
# safetensors                        0.4.5
# scikit-image                       0.24.0
# scikit-learn                       1.5.2
# scipy                              1.13.1
# scooby                             0.10.0
# scs                                3.2.7
# seaborn                            0.13.2
# SecretStorage                      3.3.1
# Send2Trash                         1.8.3
# sentence-transformers              3.2.1
# sentencepiece                      0.2.0
# sentry-sdk                         2.17.0
# setproctitle                       1.3.3
# setuptools                         75.1.0
# shap                               0.46.0
# shapely                            2.0.6
# shellingham                        1.5.4
# simple-parsing                     0.1.6
# six                                1.16.0
# sklearn-pandas                     2.2.0
# slicer                             0.0.8
# smart-open                         7.0.5
# smmap                              5.0.1
# sniffio                            1.3.1
# snowballstemmer                    2.2.0
# soundfile                          0.12.1
# soupsieve                          2.6
# soxr                               0.5.0.post1
# spacy                              3.7.5
# spacy-legacy                       3.0.12
# spacy-loggers                      1.0.5
# Sphinx                             5.0.2
# sphinxcontrib-applehelp            2.0.0
# sphinxcontrib-devhelp              2.0.0
# sphinxcontrib-htmlhelp             2.1.0
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               2.0.0
# sphinxcontrib-serializinghtml      2.0.0
# SQLAlchemy                         2.0.36
# sqlglot                            25.1.0
# sqlparse                           0.5.1
# srsly                              2.4.8
# stanio                             0.5.1
# statsmodels                        0.14.4
# StrEnum                            0.4.15
# stringzilla                        3.10.6
# sympy                              1.13.1
# tables                             3.8.0
# tabulate                           0.9.0
# tbb                                2021.13.1
# tcmlib                             1.2.0
# tenacity                           9.0.0
# tensorboard                        2.17.0
# tensorboard-data-server            0.7.2
# tensorflow                         2.17.0
# tensorflow-datasets                4.9.6
# tensorflow-hub                     0.16.1
# tensorflow-io-gcs-filesystem       0.37.1
# tensorflow-metadata                1.16.1
# tensorflow-probability             0.24.0
# tensorstore                        0.1.67
# termcolor                          2.5.0
# terminado                          0.18.1
# text-unidecode                     1.3
# textblob                           0.17.1
# tf_keras                           2.17.0
# tf-slim                            1.1.0
# thinc                              8.2.5
# threadpoolctl                      3.5.0
# tifffile                           2024.9.20
# timm                               1.0.11
# tinycss2                           1.4.0
# tokenizers                         0.19.1
# toml                               0.10.2
# tomli                              2.0.2
# toolz                              0.12.1
# torch                              2.5.0+cu121
# torchaudio                         2.5.0+cu121
# torchsummary                       1.5.1
# torchvision                        0.20.0+cu121
# tornado                            6.3.3
# tqdm                               4.66.6
# traitlets                          5.7.1
# traittypes                         0.2.1
# transformers                       4.44.2
# tweepy                             4.14.0
# typeguard                          4.4.0
# typer                              0.12.5
# types-pytz                         2024.2.0.20241003
# types-setuptools                   75.3.0.20241107
# typing_extensions                  4.12.2
# tzdata                             2024.2
# tzlocal                            5.2
# uc-micro-py                        1.0.3
# umf                                0.9.0
# uritemplate                        4.1.1
# urllib3                            2.2.3
# vega-datasets                      0.9.0
# wadllib                            1.3.6
# wandb                              0.18.5
# wasabi                             1.1.3
# wcwidth                            0.2.13
# weasel                             0.4.1
# webcolors                          24.8.0
# webencodings                       0.5.1
# websocket-client                   1.8.0
# Werkzeug                           3.0.6
# wheel                              0.44.0
# widgetsnbextension                 3.6.10
# wordcloud                          1.9.3
# wrapt                              1.16.0
# xarray                             2024.10.0
# xarray-einstats                    0.8.0
# xgboost                            2.1.2
# xlrd                               2.0.1
# xyzservices                        2024.9.0
# yarl                               1.17.0
# yellowbrick                        1.5
# yfinance                           0.2.48
# zipp                               3.20.2

# %%
import pandas as pd
import os
import numpy as np
import datetime
from datetime import datetime, timedelta
import re


# !pip install pyxlsb
import pyxlsb
import pandas as pd
from openpyxl import load_workbook

# Suppress warnings
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# Mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Collecting pyxlsb
#   Downloading pyxlsb-1.0.10-py2.py3-none-any.whl (23 kB)
# Installing collected packages: pyxlsb
# Successfully installed pyxlsb-1.0.10
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 🟥 Functions

# %%
########################################################################################################################################################################################################################
########################################################################################################################################################################################################################

def extract_sheet_names(file_path):
    if file_path.endswith('.xlsb'):
        # Handle XLSB files
        with pyxlsb.open_workbook(file_path) as xlsb:
            sheet_names = [sheetname for sheetname in xlsb.sheets]
    else:
        # Handle XLSX or XLS files
        xls = pd.ExcelFile(file_path)
        sheet_names = xls.sheet_names

    return sheet_names

########################################################################################################################################################################################################################
########################################################################################################################################################################################################################

def extract_garment_type(file_path, sheet_garment_mapping):

    for sheet_name, garment_type in sheet_garment_mapping:
        # Read the specific sheet
        try:
          df = pd.read_excel(file_path, sheet_name=sheet_name, header=None)
        except:
          continue

        # Find the row where the second column (index 1) has "Garment type:"
        row = df[df[1] == "Garment type:"]

        # Check the third column (index 2) for the expected garment type
        if not row.empty and row.iloc[0, 2] == garment_type:
            return garment_type

########################################################################################################################################################################################################################
########################################################################################################################################################################################################################

def assess_main_info_column(file_path, sheet_names):

  #Returns 0 or 1 or 2, depending on which column holds the dimensions (QC provider, Supplier, etc).

    for sheet_name in sheet_names:

      # Check if sheet name exists
      try:
        df = pd.read_excel(file_path, sheet_name=sheet_name, header=None)
      except:
        continue

      # Check if main info column candidate has supplier/po descriptions. Try columns 1, 2, 3
      for main_info_column in (0, 1, 2):

        supplier_row = df[df[main_info_column] == 'Supplier:']
        po_row = df[df[main_info_column] == 'PO number:']

        if supplier_row.empty and po_row.empty:
          continue
        else:
          return main_info_column

    print('🔴 Main info column not found (neither 0 nor 1 nor 2)')
    return 'Not found'

########################################################################################################################################################################################################################

def assess_sheet_name(file_path, sheet_names, main_info_column):


    if file_path.endswith('PTR.23.00700.4101_RESPOKE_VIPALTEX_21.09.2023_HEAVY T-SHIRT_SCARAB_VIPALTEX1MANU648_ QC (1).xlsx'):
      return 'DATA TOPS'
    if file_path.endswith('PTR.23.00700.4101_RESPOKE_VIPALTEX_21.09.2023_HEAVY T-SHIRT_SCARAB_VIPALTEX1MANU648_ QC.xlsx'):
      return 'DATA TOPS'
    if file_path.endswith('PTR23.00604_Respoke_Ritedu_2023_08_04_Cord Shirt_Dark Navy_RITEDU20MANU620_IR.xlsx'):
      return 'DATA TOPS'
    if file_path.endswith('PTR23.00605_Respoke_Ritedu_2023_08_04_Cord Shirt_Tawny Port_RITEDU20MANU620_IR.xlsx'):
      return 'DATA TOPS'
    if file_path.endswith('RITEDU22MANU659_IR_CHAMBRAY.xlsx'):
      return 'DATA TOPS'
    if file_path.endswith('2023_11_27_RITEDU22MANU659 DARK_CHAMBRAY.xlsx'):
      return 'DATA TOPS'

    for sheet_name in sheet_names:

      # Check if sheet name exists
      try:
        df = pd.read_excel(file_path, sheet_name=sheet_name, header=None)
      except:
        continue


      # Check whether it's the right sheet by looking at supplier and PO number values
      supplier_row = df[df[main_info_column] == 'Supplier:']
      supplier_value = supplier_row.iloc[0, main_info_column + 1]

      po_row = df[df[main_info_column] == 'PO number:']
      po_value = po_row.iloc[0, main_info_column + 1]

      if pd.notna(supplier_value) or pd.notna(po_value):
        return sheet_name
      else:
        continue

    print('🔴 Sheet name with data summary not found (neither DATA TROUSERS, nor DATA TOPS, nor DATA BOXERS)')
    return 'Not found'

########################################################################################################################################################################################################################

def extract_file_summary(file_path, qc_files_fields_to_extract, sheet_name, main_info_column):

    # Read sheet containing summary
    df = pd.read_excel(file_path, sheet_name=sheet_name, header=None)

    # Initialise field values list
    field_values = []

    # Loop over fields to extract
    for field_name in qc_files_fields_to_extract:

      row = df[df[main_info_column] == field_name]

      # If field does not exist in main column then add '' as its value, else get its value from next column and append to field values list
      if row.empty:
        field_value = ''
      else:
        field_value = row.iloc[0, main_info_column+1]

      field_values.append(field_value)

    # Create and return dataframe containing row of QC File summary
    qc_file_summary = pd.DataFrame([field_values], columns=qc_files_fields_to_extract)
    # display(qc_file_summary)
    # qc_file_summary = transform_qc_files(qc_file_summary)
    return qc_file_summary

########################################################################################################################################################################################################################
########################################################################################################################################################################################################################

def extract_qc_units(file_path, qc_units_sheet, garment_type):

  df = pd.read_excel(file_path, sheet_name=qc_units_sheet, header=None)

  columns_to_extract = [1, 2, 3, 4, 8, 9, 13, 14, 18, 19, 23, 24, 28, 29, 33, 34, 38, 39]
  starting_row = 3

  if garment_type == 'Tops':
    qc_units = df.iloc[starting_row:, columns_to_extract].copy()
    qc_units.columns = qc_units_tops_fields
    qc_units = qc_units[qc_units['unit_size'].notna()].reset_index(drop=True)

  elif garment_type == 'Trousers':

    qc_units = df.iloc[starting_row:, columns_to_extract].copy()
    qc_units.columns = qc_units_trousers_fields
    qc_units = qc_units[qc_units['unit_size'].notna()].reset_index(drop=True)

  else:
    print('Logic for this garment_type not yet added. Skipping unit extraction')

  return qc_units

########################################################################################################################################################################################################################
########################################################################################################################################################################################################################

def create_qc_files_table(folder_path, sheet_names, qc_files_fields_to_extract, max_files=500):

    # Step 1: Initialise qc files df
    qc_files = pd.DataFrame(columns=qc_files_fields_to_extract + ['file_name'])
    qc_files_list = []

    # Step 2: Loop through folder containing QC Files and append to qc_files table
    file_count = 1
    total_files = len(os.listdir(folder_path))

    for file_name in os.listdir(folder_path):
        if file_count > max_files:
            break

        # Get QC File path
        file_path = os.path.join(folder_path, file_name)

        # Display progress
        print(f'📁 {file_count} / {total_files} Processing File: {file_name}')

        # Get main info column (in which column is summary held? 1, 2, or 3)
        main_info_column = assess_main_info_column(file_path, sheet_names)

        # Get main sheet name (in which sheet is summary held? Tops, Trousers, or Boxers?)
        sheet_name = assess_sheet_name(file_path, sheet_names, main_info_column)

        # Extract File Summary for QC File
        try:
            file_summary = extract_file_summary(file_path, qc_files_fields_to_extract, sheet_name, main_info_column)
            file_summary['file_name'] = file_name
            qc_files_list.append(file_summary)
        except Exception as e:
            print(f'🔴 Failed to process summary for this file: {e}.')
            # print(f'File Summary: \n')
            # display(file_summary)

        file_count += 1

    # Step 3: Concatenate all QC File DFs
    qc_files = pd.concat(qc_files_list, ignore_index=True)

    # Step 4: Add folder_name field
    qc_files['folder_name'] = os.path.basename(folder_path)

    qc_files = qc_files.reset_index(drop=True)

    # Step 5: Return QC Files table
    return qc_files

########################################################################################################################################################################################################################
########################################################################################################################################################################################################################

def clean_date(date):
    """
    Cleans and standardizes the date to the 'YYYY-MM-DD' format, including additional formats like 'DD.MM.YYYY'
    and Excel date format (days since 1900-01-01).

    Args:
    date (str or int): The date in various formats, including integer for Excel date format.

    Returns:
    str: The standardized date string in 'YYYY-MM-DD' format, or the original date if not parsable.
    """
    for fmt in ("%d/%m/%Y", "%Y-%m-%d %H:%M:%S", "%Y-%m-%d", "%d.%m.%Y"):
        try:
            return datetime.strptime(str(date), fmt).date().isoformat()
        except (ValueError, TypeError):
            continue

    # Handle Excel date format (days since 1900-01-01)
    try:
        if isinstance(date, (int, float)) and date > 0:
            return (datetime(1900, 1, 1) + pd.Timedelta(days=date-2)).date().isoformat()  # Adjusting for Excel's leap year bug
    except Exception as e:
        pass

    # Return the original date if not parsable
    return date

# For entries in quantities like: 307 (22 cartons)
def extract_first_number(s):
    match = re.search(r'\d+', s)
    return match.group(0) if match else ''

def transform_qc_files(qc_files):
    # Rename columns
    qc_files = qc_files.rename(columns={
                                        'QC PASS/FAIL': 'qc_result',
                                        'Inspection Type (to be completed by Spoke):': 'inspection_type',
                                        'Number of units rejected on measurement': 'units_rejected_measurement',
                                        'Number of units rejected on quality': 'units_rejected_quality',
                                        'Number of units rejected on quality - Major': 'units_rejected_quality_major',
                                        'Number of units rejected on quality - Minor': 'units_rejected_quality_minor',
                                        'Number of units rejected on quality - Critical': 'units_rejected_quality_critical',
                                        'Style/Material/Colour - Conform': 'conform_style',
                                        'Packing - Conform': 'conform_packing',
                                        'Marking/Label (barcodes readable and matching product) - Conform': 'conform_label',
                                        'Odour test - Conform': 'conform_odour',
                                        'Hem (Shorts only)': 'hem'
                                        })

    # Reformat column names
    qc_files.columns = qc_files.columns.str.rstrip(':').str.strip().str.lower().str.replace(' ', '_')

    # Reformat string fields (trim and capitalise)
    string_fields = ['inspection_type', 'qc_provider', 'supplier', 'supplier_country', 'po_number', 'garment_type', 'style', 'colour']

    for string_field in string_fields:
      qc_files[string_field] = qc_files[string_field].str.strip().str.upper()

    # Add file_id (PO + Style + Colour + Fit)
    qc_files['file_id'] = qc_files['inspection_type'].astype(str) + ' | ' + qc_files['po_number'].astype(str) + ' | ' + qc_files['style'].astype(str) + ' | ' + qc_files['colour'].astype(str)
    qc_files['batch_id'] = qc_files['po_number'].astype(str) + ' | ' + qc_files['style'].astype(str) + ' | ' + qc_files['colour'].astype(str)

    # Clean dates using "clean_date" function
    qc_files['date_of_inspection'] = qc_files['date_of_inspection'].apply(lambda x: clean_date(x))

    # Clean entries in quantities like: 307 (22 cartons) by keeping the first number
    unclean_fields = ['qty_declared', 'qty_packed']

    for field in unclean_fields:
      qc_files[field] = qc_files[field].astype(str)
      qc_files[field] = qc_files[field].apply(lambda x: extract_first_number(x))

    # Reorder Columns
    # qc_files = qc_files[['file_name', 'file_id', 'po_number', 'garment_type', 'style', 'colour', 'qc_provider', 'supplier', 'supplier_country', 'date_of_inspection', 'order_qty', 'units_inspected', 'units_measured', 'qc_result']]

    return qc_files

# %% [markdown]
# ## 🟥 Inputs

# %%
# Sheet names that can hold summary data
sheet_names = ('DATA TROUSERS', 'DATA TOPS', 'DATA BOXERS')

# QC Files: Fields to extract from summary page
qc_files_fields_to_extract = [
                            'Inspection Type (to be completed by Spoke):',
                            'QC provider:',
                            'Supplier:',
                            'Supplier country:',
                            'Date of inspection:',
                            'PO number:',
                            'Garment type:',
                            'Style:',
                            'Colour:',

                            'Style/Material/Colour - Conform',
                            'Packing - Conform',
                            'Marking/Label (barcodes readable and matching product) - Conform',
                            'Odour test - Conform',

                            'Order QTY:',
                            'QTY declared:',
                            'QTY packed:',
                            'Units inspected:',
                            'Units measured:',
                            'Number of units rejected on measurement',
                            'Number of units rejected on quality',
                            'Number of units rejected on quality - Major',
                            'Number of units rejected on quality - Minor',
                            'Number of units rejected on quality - Critical',

                            'Waist','Hip','Front rise','Back rise','Thigh','Knee','Hem (Shorts only)',

                            'Chest','Front Length','Sleeve Length','Muscle','Cuff Width','Neck Circ', # They have waist too but I'm removing it for now bc we get it from trousers ones before. Keep it in mind tho in case functionality changes

                            'QC PASS/FAIL']

# %% [markdown]
# ## 🟥 Run

# %%
folder_path_aw23 = '/content/drive/MyDrive/QC_files_AW23'
folder_path_ss24 = '/content/drive/MyDrive/QC_files_SS24'

qc_files_aw23 = create_qc_files_table(folder_path_aw23, sheet_names, qc_files_fields_to_extract, max_files=500)
qc_files_ss24 = create_qc_files_table(folder_path_ss24, sheet_names, qc_files_fields_to_extract, max_files=500)
# Out:
# 📁 1 / 204 Processing File: KAYNAK13MANU640 New Rise BLACK  (BLACK ONYX) reg.xlsx
# 📁 2 / 204 Processing File: KAYNAK13MANU640 New Rise BLACK  (BLACK ONYX) taper.xlsx
# 📁 3 / 204 Processing File: KAYNAK13MANU640 New Rise FLINTSTONE (INFINITY) reg.xlsx
# 📁 4 / 204 Processing File: KAYNAK13MANU640 New Rise FLINTSTONE (INFINITY) taper.xlsx
# 📁 5 / 204 Processing File: KAYNAK13MANU640 New Rise ICEBERG (QUARRY) taper.xlsx
# 📁 6 / 204 Processing File: KAYNAK13MANU640 New Rise MAROON (RHUBARB) taper.xlsx
# 📁 7 / 204 Processing File: KAYNAK13MANU640 New Rise SAGE (ICEBERG GREEN) reg.xlsx
# 📁 8 / 204 Processing File: KAYNAK13MANU640 New Rise SAGE (ICEBERG GREEN) taper.xlsx
# 📁 9 / 204 Processing File: KAYNAK14MANU642 New Rise medieval blue taper.xlsx
# 📁 10 / 204 Processing File: KAYNAK14MANU642 New Rise medieval blue reg.xlsx
# 📁 11 / 204 Processing File: KAYNAK13MANU640 New Rise MAROON (RHUBARB) reg.xlsx
# 📁 12 / 204 Processing File: KAYNAK13MANU640 ICEBERG New Rise (QUARRY).xlsx
# 📁 13 / 204 Processing File: KAYNAK13MANU640 New Rise KHAKI TAPER.xlsx
# 📁 14 / 204 Processing File: KAYNAK13MANU640 New Rise KHAKI REG.xlsx
# 📁 15 / 204 Processing File: HKS2MANU684 NAVY STRAIGHT.xlsx
# 📁 16 / 204 Processing File: BLRWT00002174_RESPOKE-IMPULSE_PO_IMPULSE13MANU607_BITTER CHOCOLATE_WINTER HEROES_MMT (1).xlsx
# 📁 17 / 204 Processing File: PTR23.00752.4101_RESPOKE_VIPALTEX_VIPALTEX1MANU648_HEAVYSHIRT_WHITE_3_OCT.xlsx
# 📁 18 / 204 Processing File: PTR23.00753.4101_RESPOKE_VIPALTEX_VIPALTEX1MANU648_HEAVYSHIRT_NAVY_3_Oct.xlsx
# 📁 19 / 204 Processing File: HKS2MANU684 SLIM GREY MARL.xlsx
# 📁 20 / 204 Processing File: PO-HKS2MANU684 STRAIGHT GREY MARL.xlsx
# 📁 21 / 204 Processing File: PTR23.00966_RESPOKE_ECOVESTE_2023_12_05_ BOXERS LEG LENGTH 3_ ECOVEST2MANU700.xlsx
# 📁 22 / 204 Processing File: HKS2MANU684 NAVY SLIM.xlsx
# 📁 23 / 204 Processing File: PTR23.00773_RESPOKE_LAMOSA_2023_10_11_ FIVES CORD NAVY_ LAMOSA69MANU630.xlsx
# 📁 24 / 204 Processing File: PTR.23.00755.4101_RESPOKE_VIPALTEX_03.10.2023_HEAVY T-SHIRT_SCARAB_VIPALTEX1MANU648_ QC.xlsx
# 📁 25 / 204 Processing File: PTR.23.00700.4101_RESPOKE_VIPALTEX_21.09.2023_HEAVY T-SHIRT_NAVY_VIPALTE....xlsx
# 📁 26 / 204 Processing File: ECOVEST_05.12.2023_BOXERS_NAVY_ECOVEST2MANU700_ QC.xlsx
# 📁 27 / 204 Processing File: HKS2 OATMEAL STRAIGHT.xlsx
# 📁 28 / 204 Processing File: PTR23.00781.4101_RESPOKE_ECOVEST_2023_10_11_ ECOVESTT1MANU596_1R_ NAVY.xlsx
# 📁 29 / 204 Processing File: PTR23.00777.4101_RESPOKE_LAMOSA_LAMOSA69MANU630_.CORD FIVES_GRISAILLE_10_10.xlsx
# 📁 30 / 204 Processing File: PTR23.00780.4101_RESPOKE_ ECOVEST_2023_10_11_ECOVESTT1MANU595_IR_BLACK.xlsx
# 📁 31 / 204 Processing File: KAYNAK15MANU658 - CARAMEL (CARAMEL CAFÉ).xlsx
# 📁 32 / 204 Processing File: PTR23.00783.4101_RESPOKE_ECOVEST_BOXERS_BLACK_11_10_ECOVESTT1MANU596_1R.xlsx
# 📁 33 / 204 Processing File: KAYNAK15MANU658 - FOREST (SCARAB).xlsx
# 📁 34 / 204 Processing File: PTR23.00772_RESPOKE_LAMOSA_2023_10_10_ FIVES CORD IVY GREEN_ LAMOSA70MANU637.xlsx
# 📁 35 / 204 Processing File: BLRWT00002174_RESPOKE-IMPULSE_PO_IMPULSE13MANU607_BITTER CHOCOLATE_WINTER HEROES_MMT.xlsx
# 📁 36 / 204 Processing File: HKS2 OATMEAL SLIM.xlsx
# 📁 37 / 204 Processing File: PTR23.00779.4101_RESPOKE_LAMOSA _ 2023_10_10_MANU 69MANU630_FAWN_IR.xlsx
# 📁 38 / 204 Processing File: PTR23.00701.4101_RESPOKE_VIPALTEX_VIPALTEX1MANU648_HEAVYSHIRT_WHITE.xlsx
# 📁 39 / 204 Processing File: PTR23.00776.4101_RESPOKE_LAMOSA_LAMOSA69MANU630_CORD FIVES_FEATHER GREY_10_10.xlsx
# 📁 40 / 204 Processing File: PTR23.00784.4101_RESPOKE_ECOVEST_BOXERS_SCARAB_11_10_ECOVESTT1MANU596_1R.xlsx
# 📁 41 / 204 Processing File: PTR23.00701.4101_RESPOKE_VIPALTEX_VIPALTEX1MANU648_HEAVYSHIRT_WHITE (1).xlsx
# 📁 42 / 204 Processing File: PTR23.00687_Respoke_Sartius_2023_09_19_Winter Smarts_Blue Herringbone_SARTIUS22MANU643_IR.xlsx
# 📁 43 / 204 Processing File: PTR23.00670.4101_RESPOKE_LAMOSA_11_09_2023_LAMOSA67MANU617_Trousers_Brick_Red.xlsx
# 📁 44 / 204 Processing File: PTR23.00686_Respoke_Sartius_2023_09_19_Santa Pant_Red_SARTIUS22MANU643_IR.xlsx
# 📁 45 / 204 Processing File: BLRWT00002215_RESPOKE-IMPULSE_PO_IMPULSE15MANU629_CROWN BLUE_HEROES_MMT.xlsb
# 📁 46 / 204 Processing File: BLRWT00002171_RESPOKE-IMPULSE_PO_IMPULSE13MANU607_DARK NAVY_WINTER HEROES_MMT.xlsx
# 📁 47 / 204 Processing File: BLRWT00002211_RESPOKE-IMPULSE_PO_IMPULSE15MANU629_BLACK ONYX_HEROES_MMT.xlsb
# 📁 48 / 204 Processing File: BLRWT00002216_RESPOKE-IMPULSE_PO_IMPULSE15MANU629_GRAPHITE_HEROES TAPER_MMT.xlsb
# 📁 49 / 204 Processing File: BLRWT00002172_RESPOKE-IMPULSE_PO_IMPULSE13MANU607_DEEP FOREST_WINTER HEROES_MMT.xlsx
# 📁 50 / 204 Processing File: PTR.23.00700.4101_RESPOKE_VIPALTEX_21.09.2023_HEAVY T-SHIRT_SCARAB_VIPALTEX1MANU648_ QC (1).xlsx
# 📁 51 / 204 Processing File: BLRWT00002173_RESPOKE-IMPULSE_PO_IMPULSE13MANU607_BEECH_WINTER HEROES_MMT (1).xlsx
# 📁 52 / 204 Processing File: PTR.23.00700.4101_RESPOKE_VIPALTEX_21.09.2023_HEAVY T-SHIRT_SCARAB_VIPALTEX1MANU648_ QC.xlsx
# 📁 53 / 204 Processing File: FRI Report - 40317390-02 - Respoke Limited - PO#TAL17MANU636 - Style#TRAVEL SHARPS - VINTAGE INDIGO - 18 Sep 2023.xlsx
# 📁 54 / 204 Processing File: BLRWT00002173_RESPOKE-IMPULSE_PO_IMPULSE13MANU607_BEECH_WINTER HEROES_MMT.xlsx
# 📁 55 / 204 Processing File: FRI Report - 40317390-01- Respoke Limited - PO#TAL17MANU636 - Style#TRAVEL SHARPS - STORMY WEATHER- 18 Sep 2023.xlsx
# 📁 56 / 204 Processing File: PTR23.00679.4101_RESPOKE_VALERIUS_2023_09_14_VALERIUS62MANU641_IR_QUARRY.xlsx
# 📁 57 / 204 Processing File: PTR23.00677.4101_RESPOKE_VALERIUS_14_09_VALERIUS62MANU641_LSTHIRT_NAVY.xlsx
# 📁 58 / 204 Processing File: PTR23.00702.4101_RESPOKE_VIPALTEX_VIPALTEX1MANU648_HEAVYSHIRT_NAVY.xlsx
# 📁 59 / 204 Processing File: PTR23.00678.4101_RESPOKE_VALERIUS_2023_09_14_VALERIUS62MANU641_IR_ WHITE.xlsx
# 📁 60 / 204 Processing File: BLRWT00002212_RESPOKE-IMPULSE_PO_IMPULSE15MANU629_INFINITY_HEROES TAPER_MMT.xlsb
# 📁 61 / 204 Processing File: HEROES Taper ICEBERG (QUARRY) BV_son ölçü.xlsx
# 📁 62 / 204 Processing File: LKRWT00006830-STAR10MANU625-Style_CAHMERE SHARPS.xlsx
# 📁 63 / 204 Processing File: LKRWT00006810_STAR10MANU625_Style-CORD SHARPS.xlsx
# 📁 64 / 204 Processing File: HEROES Taper Olive BV 16.08.xlsx
# 📁 65 / 204 Processing File: BLRWT00002210_RESPOKE-IMPULSE_PO_IMPULSE15MANU629_OLIVE_HEROES TAPER_MMT.xlsb
# 📁 66 / 204 Processing File: HEROES reg OliveBV 16.08.xlsx
# 📁 67 / 204 Processing File: PTR23.00671.4101_RESPOKE_LAMOSA_11.09.2023_MOLESKIN FIVES_COFFEE BEAN_LAMOSA67MANU617 (2).xlsx
# 📁 68 / 204 Processing File: LKRWT00006831-STAR10MANU625-Style_CASHMERESHARPS.xlsx
# 📁 69 / 204 Processing File: LKRWT00006809_STAR10MANU625_Style-CORD SHARPS.xlsx
# 📁 70 / 204 Processing File: HEROES Taper Navy BV.xlsx
# 📁 71 / 204 Processing File: BLRWT00002209_RESPOKE-IMPULSE_PO_IMPULSE15MANU629_NAVY_HEROES_MMT.xlsb
# 📁 72 / 204 Processing File: HEROES Reg Harvest Gold BV.xlsx
# 📁 73 / 204 Processing File: HEROES Taper Onyx BV_son ölçü.xlsx
# 📁 74 / 204 Processing File: LKRWT00006807-STAR10MANU625-Style-VELVET SHARPS.xlsx
# 📁 75 / 204 Processing File: HEROES reg OliveBV.xlsx
# 📁 76 / 204 Processing File: BLRWT00002210_RESPOKE-IMPULSE_PO_IMPULSE15MANU629_OLIVE_HEROES_MMT.xlsb
# 📁 77 / 204 Processing File: PTR23.00609.4101_RESPOKE_RITEDU_07_08_2023_ RITEDU20MANU620_BIRCH_IR...xlsx
# 📁 78 / 204 Processing File: HEROES Taper Smoked Navy (Crown Blue) BV.xlsx
# 📁 79 / 204 Processing File: HEROES Reg ICEBERG (QUARRY) BV_son ölçü.xlsx
# 📁 80 / 204 Processing File: HEROES Taper Navy BV 16.08.xlsx
# 📁 81 / 204 Processing File: HEROES Reg Ammonite BV_16.08.xlsx
# 📁 82 / 204 Processing File: LKRWT00006808_STAR10MANU625_Style-VELVET SHARPS.xlsx
# 📁 83 / 204 Processing File: HEROES Taper Olive BV.xlsx
# 📁 84 / 204 Processing File: HEROES Reg Ammonite BV_son ölçü.xlsx
# 📁 85 / 204 Processing File: PTR23. 00613.4101_RESPOKE_LAMOSA _2023_08_07_LAMOSA68MANU618_IR_ BLACKEND PEARL.xlsx
# 📁 86 / 204 Processing File: PTR23. 00612.4101_RESPOKE_LAMOSA _2023_08_07_LAMOSA68MANU618_IR_ CARAMEL CAFÉ.xlsx
# 📁 87 / 204 Processing File: PTR23.00622_Respoke_Lamosa_2023_08_09_Moleskin Fives_Deep Space_LAMOSA67MANU617_IR.xlsx
# 📁 88 / 204 Processing File: PTR23.00623_Respoke_Lamosa_2023_08_10_Moleskin Fives_Ivy Green_LAMOSA67MANU617_IR.xlsx
# 📁 89 / 204 Processing File: PTR23.00607.4101_RESPOKE_RITEDU_31_07_2023_ RITEDU20MANU620_SCRAB_IR....xlsx
# 📁 90 / 204 Processing File: PTR23.00604_Respoke_Ritedu_2023_08_04_Cord Shirt_Dark Navy_RITEDU20MANU620_IR.xlsx
# 📁 91 / 204 Processing File: PTR23.00608.4101_RESPOKE_RITEDU_04_08_2023_ RITEDU20MANU620_MAUVE SHADOWS_IR....xlsx
# 📁 92 / 204 Processing File: HEROES TAPER BV (1).xlsx
# 📁 93 / 204 Processing File: PTR23.00624_RESPOKE_LAMOSA_2023_08_09_ Moleskin Fives_Harvest Gold_ LAMOSA67MANU617.xlsx
# 📁 94 / 204 Processing File: HEROES BV.xlsx
# 📁 95 / 204 Processing File: PTR23.00599_RESPOKE_VALERIUS_2023_08_04_VALERIUS65MANU647_TSHIRT_GREEN GABLES.xlsx
# 📁 96 / 204 Processing File: HEROES TAPER BV.xlsx
# 📁 97 / 204 Processing File: PTR23.00603_RESPOKE_LAMOSA_2023_08_06_ FIVES CORD IVY GREEN_ LAMOSA68MANU618_IR.xlsx
# 📁 98 / 204 Processing File: PTR23.00581.4101_RESPOKE_RITEDU_2023_07_31_RITEDU19MANU619_MARRON CHECK _IR.xlsx
# 📁 99 / 204 Processing File: PTR23.00605_Respoke_Ritedu_2023_08_04_Cord Shirt_Tawny Port_RITEDU20MANU620_IR.xlsx
# 📁 100 / 204 Processing File: PTR23.00580.4101_RESPOKE_RITEDU_31_07_2023_ RITEDU19MANU619_STONE_IR.xlsx
# 📁 101 / 204 Processing File: PTR23.00579.4101_RESPOKE_RITEDU_31_07_2023_ RITEDU19MANU619_OLIVE_IR.xlsx
# 📁 102 / 204 Processing File: PTR23.00598_RESPOKE_VALERIUS_2023_08_03_VALERIUS65MANU647_TSHIRT_RHUBARB.xlsx
# 📁 103 / 204 Processing File: 12.09 ITALIAN DENIM 7YEARS.xlsx
# 📁 104 / 204 Processing File: FRI Report - 40337174-02 - Respoke Limited - PO#SAITEX13MANU649 - Style#HEROES - DIJON - 28 DEC 2023.xlsx
# 📁 105 / 204 Processing File: FRI Report - 40337174-04 - Respoke Limited - PO#SAITEX13MANU649 - Style#HEROES TAPER - COFFEE BEAN - 28 DEC 2023.xlsx
# 📁 106 / 204 Processing File: FRI Report - 40337174-03 - Respoke Limited - PO#SAITEX13MANU649 - Style#HEROES TAPER - DIJON - 28 DEC 2023.xlsx
# 📁 107 / 204 Processing File: FRI Report - 40337174-01 - Respoke Limited - PO#SAITEX13MANU649 - Style#HEROES - COFFEE BEAN  - 28 DEC 2023.xlsx
# 📁 108 / 204 Processing File: FRI Report - 40319298-01 - Respoke Limited - PO#SAITEX12MANU639 - Style#12 OZ DENIM - BROKEN IN  - 19 Sep 2023 (1).xlsx
# 📁 109 / 204 Processing File: FRI Report - 40319298-01 - Respoke Limited - PO#SAITEX12MANU639 - Style#12 OZ DENIM - BROKEN IN  - 19 Sep 2023 (2).xlsx
# 📁 110 / 204 Processing File: FRI Report - 40319298-01 - Respoke Limited - PO#SAITEX12MANU639 - Style#12 OZ DENIM - BROKEN IN  - 19 Sep 2023.xlsx
# 📁 111 / 204 Processing File: PTR.23.00700.4101_RESPOKE_VIPALTEX_21.09.2023_HEAVY T-SHIRT_SCARAB_VIPAL....xlsx
# 📁 112 / 204 Processing File: HEROES TAPER BV KAYNAK9MANU624.xlsx
# 📁 113 / 204 Processing File: HEROES BV KAYNAK9MANU624.xlsx
# 📁 114 / 204 Processing File: LKRWT00007097_STAR9MANU614_SHARPS TAPER (1).XLSX
# 📁 115 / 204 Processing File: LKRWT00007096_STAR9MANU614_SHARPS TAPER (1).xlsx
# 📁 116 / 204 Processing File: LKRWT00007107_STAR9MANU614_SHARPS (1).xlsx
# 📁 117 / 204 Processing File: LKRWT00007106_STAR9MANU614-_SHARPS .XLSX
# 📁 118 / 204 Processing File: KAYNAK12MANU638HEROESOLIVETAPER BV 10232212027_MMT3.xlsx
# 📁 119 / 204 Processing File: KAYNAK12MANU638 - HEROES - TAPER - NAVY 10232212027_MMT4.xlsx
# 📁 120 / 204 Processing File: KAYNAK12MANU638 HEROES TAPER SMOKED NAVY (CROWN BLU)10232212027_MMT1.xlsx
# 📁 121 / 204 Processing File: KAYNAK12MANU638 - HEROES - ONYX - TAPER 10232212027_MMT2.xlsx
# 📁 122 / 204 Processing File: KAYNAK12MANU638 - HEROES - OLIVE 10232212027_MMT6.xlsx
# 📁 123 / 204 Processing File: KAYNAK12MANU638 - HEROES - TAPER - ICEBERG (QUARRY) 10232212027_MMT5.xlsx
# 📁 124 / 204 Processing File: KAYNAK12MANU638 - HEROES - HARVEST GOLD - 10232212027_MMT8.xlsx
# 📁 125 / 204 Processing File: FRI Report - 40311719-04 - Respoke Limited - PO#SAITEX11MANU628 - Style#12 OZ DENIM TAPER - BLACK - 28-Jul-2023 (1).xlsx
# 📁 126 / 204 Processing File: FRI Report - 40311719-03 - Respoke Limited - PO#SAITEX11MANU628 - Style#12 OZ DENIM - BLACK - 28-Jul-2023.xlsx
# 📁 127 / 204 Processing File: FRI Report - 40311719-02 - Respoke Limited - PO#SAITEX11MANU628 - Style#12 OZ DENIM TAPER - RINSE - 28-Jul-2023.xlsx
# 📁 128 / 204 Processing File: FRI Report - 40311719-01 - Respoke Limited - PO#SAITEX11MANU628 - Style#12 OZ DENIM - RINSE - 28-Jul-2023.xlsx
# 📁 129 / 204 Processing File: PTR24.00088.4101_RESPOKE_ECOVEST_BOXERS 3IN_SCARAB_ECOVEST2MANU700_2024 QC MASTER FILE.xlsx
# 📁 130 / 204 Processing File: PTR24.00089.4101_RESPOKE_ECOVEST_BOXERS 5IN_SCARAB_ECOVEST2MANU700_2024 QC MASTER FILE.xlsx
# 📁 131 / 204 Processing File: IMPULSE1MANU604 HEROES TAPER AMMONITE.xlsx
# 📁 132 / 204 Processing File: IMPULSE11MANU605 HEROES TAPER INFINITY.xlsx
# 📁 133 / 204 Processing File: IMPULSE12MANU606_NAVY_HEROES _MMT.xlsx
# 📁 134 / 204 Processing File: RITEDU18MANU608_OXFORD SHIRT_GREY MARL_IR 2.xlsx
# 📁 135 / 204 Processing File: RITEDU18MANU608_OXFORD SHIRT_GREY MARL_IR.xlsx
# 📁 136 / 204 Processing File: IMPULSE11MANU605 HEROES TAPER OLIVE.xlsx
# 📁 137 / 204 Processing File: IMPULSE11MANU605 HEROES REG OLIVE.xlsx
# 📁 138 / 204 Processing File: RITEDU18MANU608_ IR DARK_CAMBRAY.xlsx
# 📁 139 / 204 Processing File: RITEDU18MANU608_ IR CAMBRAY.xlsx
# 📁 140 / 204 Processing File: RITEDU18MANU608_WHITE_IR.xlsx
# 📁 141 / 204 Processing File: IMPULSE11MANU605 HEROES INFINITY.xlsx
# 📁 142 / 204 Processing File: RITEDU18MANU608 OXFORD SHIRT_SKY_IR.xlsx
# 📁 143 / 204 Processing File: IMPULSE12MANU606 HEROES TAPER GRAPHITE.xlsx
# 📁 144 / 204 Processing File: SAITEX11MANU628 12 OZ DENIM TAPER - BLACK.xlsx
# 📁 145 / 204 Processing File: LAMOSA64MANU568 NANTUCKET_SKY CAPTAIN.xlsx
# 📁 146 / 204 Processing File: SAITEX10MANU627 12 OZ DENIM - BROKEN IN.xlsx
# 📁 147 / 204 Processing File: IMPULSE12MANU606 HEROES GRAPHITE.xlsx
# 📁 148 / 204 Processing File: IMPULSE11MANU605_INFINITY_HERO_HEROES TAPER_MMT_Regular.xlsx
# 📁 149 / 204 Processing File: IMPULSE11MANU606_NAVY_HEROES TAPER_MMT 2.xlsx
# 📁 150 / 204 Processing File: IMPULSE11MANU606_NAVY_HEROES TAPER_MMT.xlsx
# 📁 151 / 204 Processing File: IMPULSE10MANU604_AMMONITE_HERO_HEROES TAPER_MMT_Regular.xlsx
# 📁 152 / 204 Processing File: SAITEX11MANU628 - 12 OZ DENIM - BROKEN IN.xlsx
# 📁 153 / 204 Processing File: IMPULSE10MANU604_AMMONITE_HERO_HEROES TAPER_MMT_Taper.xlsx
# 📁 154 / 204 Processing File: IMPULSE11MANU605_INFINITY_HERO_HEROES TAPER_MMT_Taper.xlsx
# 📁 155 / 204 Processing File: IMPULSE12MANU606_GRAPHITE_HEROES TAPER.xlsx
# 📁 156 / 204 Processing File: IMPULSE11MANU606 HEROES TAPER NAVY.xlsx
# 📁 157 / 204 Processing File: IMPULSE10MAN604 HEROES TAPER AMMONITE.xlsx
# 📁 158 / 204 Processing File: LAMOSA64MANU568 Bulletproofs_Black Onyx.xlsx
# 📁 159 / 204 Processing File: SAITEX10MANU627 - 12 OZ DENIM TAPER - RINSE.xlsx
# 📁 160 / 204 Processing File: LAMOSA64MANU568 NANTUCKET_LEAD.xlsx
# 📁 161 / 204 Processing File: IMPULSE11MANU605 HEROES TAPER INFINITY 2.xlsx
# 📁 162 / 204 Processing File: SAITEX11MANU628 - 12 OZ DENIM - BLACK.xlsx
# 📁 163 / 204 Processing File: STAR9MANU614_SHARPS TAPER DARK NAVY.xlsx
# 📁 164 / 204 Processing File: SAITEX9MANU610 - 12 OZ DENIM - STAY BLACK.xlsx
# 📁 165 / 204 Processing File: IMPULSE12MANU606 - HEROES Taper Graphite.xlsx
# 📁 166 / 204 Processing File: STAR9MANU614 - SHARPS DARK NAVY.xlsx
# 📁 167 / 204 Processing File: LAMOSA64MANU568 NANTUCKET FIVES _AQUA GREY.xlsx
# 📁 168 / 204 Processing File: IMPULSE11MANU605_SCARAB_HERO.xlsx
# 📁 169 / 204 Processing File: SAITEX10MANU627 - 12 OZ DENIM TAPER - BROKEN IN.xlsx
# 📁 170 / 204 Processing File: STAR9MANU614_SHARPS CHARCOAL.xlsx
# 📁 171 / 204 Processing File: IMPULSE12MANU606_GRAPHITE_HERO_MMT.xlsx
# 📁 172 / 204 Processing File: IMPULSE11MANU605_SCARAB_HERO_MMT(1).xlsx
# 📁 173 / 204 Processing File: IMPULSE11MANU605_SCARAB_HEROES TAPER_MMT.xlsx
# 📁 174 / 204 Processing File: IMPULSE10MAN604 HEROES AMMONITE.xlsx
# 📁 175 / 204 Processing File: LAMOSA64MANU568 Bulletproofs_Quite Shade.xlsx
# 📁 176 / 204 Processing File: SAITEX10MANU627 - 12 OZ DENIM - RINSE.xlsx
# 📁 177 / 204 Processing File: SAITEX10MANU627 - 12 OZ DENIM - BROKEN IN.xlsx
# 📁 178 / 204 Processing File: STAR9MANU614_SHARPS TAPER CHARCOAL.xlsx
# 📁 179 / 204 Processing File: IMPULSE11MANU606 HEROES TAPER NAVY 2.xlsx
# 📁 180 / 204 Processing File: SAITEX10MANU627 - 12 OZ DENIM TAPER - CHARCOAL.xlsx
# 📁 181 / 204 Processing File: IMPULSE12MANU606 HEROES GRAPHITE 2.xlsx
# 📁 182 / 204 Processing File: LAMOSA64MANU568 BULLETPROOFS IVY GREEN.xlsx
# 📁 183 / 204 Processing File: IMPULSE11MANU605_SCARAB_HEROES TAPER.xlsx
# 📁 184 / 204 Processing File: FAIRPLAY69MANU633 12 OZ DENIM CHARCOAL BLACK.xlsx
# 📁 185 / 204 Processing File: FAIRPLAY67MANU626 ITALIAN DENIM 7YEARS.xlsx
# 📁 186 / 204 Processing File: FAIRPLAY70MANU644 ITALIAN DENIM HEROES RINSE.xlsx
# 📁 187 / 204 Processing File: FAIRPLAY69MANU633 HEMP BROKEN IN.xlsx
# 📁 188 / 204 Processing File: FAIRPLAY69MANU633 12 OZ TAPER INDIGO.xlsx
# 📁 189 / 204 Processing File: FAIRPLAY67MANU626 ITALIAN DENIM 5YEARS.xlsx
# 📁 190 / 204 Processing File: FAIRPLAY69MANU633 HEMP RINSE INDIGO.xlsx
# 📁 191 / 204 Processing File: FAIRPLAY65MANU591 TRAVEL DENIM BROKEN IN.xlsx
# 📁 192 / 204 Processing File: FAIRPLAY68MANU632 TRAVEL DENIM RINSE.xlsx
# 📁 193 / 204 Processing File: SAITEX10MANU627 - 12 OZ DENIM - CHARCOAL.xlsx
# 📁 194 / 204 Processing File: KAYNAK12MANU638 HEROES HARVEST GOLD.xlsx
# 📁 195 / 204 Processing File: KAYNAK12MANU638 HEROES ICEBERG (QUARRY).xlsx
# 📁 196 / 204 Processing File: KAYNAK12MANU638 HEROES AMMONITE.xlsx
# 📁 197 / 204 Processing File: KAYNAK 10232150763_MMT SHEET1.xlsx
# 📁 198 / 204 Processing File: KAYNAK 10232150763_MMT SHEET 2.xlsx
# 📁 199 / 204 Processing File: KAYNAK HEROES Taper Navy BV 16.08.xlsx
# 📁 200 / 204 Processing File: KAYNAK HEROES reg OliveBV 16.08.xlsx
# 📁 201 / 204 Processing File: KAYNAK HEROES TAPER BV.xlsx
# 📁 202 / 204 Processing File: KAYNAK HEROES Taper Olive BV 16.08.xlsx
# 📁 203 / 204 Processing File: KAYNAK HEROES Reg Ammonite BV_16.08.xlsx
# 📁 204 / 204 Processing File: KAYNAK HEROES BV.xlsx
# 📁 1 / 41 Processing File: PTR24.00009_RESPOKE_VALERIUS_2024_01_10_VALERIUS67MANU670_TSHIRT_INSIGNIABLUE.xlsx
# 📁 2 / 41 Processing File: PTR24.0004_Respoke_Lamosa_2024_01_05_Fives_Dark Navy_LAMOSA90MANU675_IR .xlsx
# 📁 3 / 41 Processing File: LKRWT00007514-Respoke-STAR14MANU668-NAVY-StylePLEATE FRONT WIDE LEG.xlsx
# 📁 4 / 41 Processing File: PTR24.00003.4101_RESPOKE_LAMOSA_05.01.2023_FIVES_LAUREL WREATH_LAMOSA80MANU674_ QC.xlsx
# 📁 5 / 41 Processing File: LKRWT00007517-Respoke-STAR13MANU654-LAUREL WREATH-StyleSHARP SHORTS.xlsx
# 📁 6 / 41 Processing File: LKRWT00007512-Respoke-STAR14MANU668-NAVY-StyleELASTICATED WAIST.xlsx
# 📁 7 / 41 Processing File: LKRWT00007494-Respoke-STAR11MANU652-SEPIA TINT-StyleSHARP SHORTS.xlsx
# 📁 8 / 41 Processing File: FRI Report - 40336409-06 - Respoke Limited - PO#TAL21MANU661 - Style#Summer SharpsCOTTON LIGHTWEIGHTS - Ashley Blue - 27 Dec 2023.xlsx
# 📁 9 / 41 Processing File: LKRWT00007513-Respoke-STAR14MANU668-ARGAN OIL-StyleELASTICATED WAIST.xlsx
# 📁 10 / 41 Processing File: LKRWT00007516-Respoke-STAR14MANU668-OLIVE-StylePLEATE FRONT WIDE LEG.xlsx
# 📁 11 / 41 Processing File: LKRWT00007495-Respoke-STAR11MANU652-DARK NAVY-StyleSHARP SHORTS.xlsx
# 📁 12 / 41 Processing File: LKRWT00007515-Respoke-STAR14MANU668-KHAKI-StylePLEATE FRONT WIDE LEG.xlsx
# 📁 13 / 41 Processing File: PTR24.00010_RESPOKE_VALERIUS_2024_01_10_VALERIUS67MANU670_TSHIRT_PERISCOPEECRU.xlsx
# 📁 14 / 41 Processing File: FRI Report - 40336409-03-R1 - Respoke Limited - PO#TAL21MANU661 - Style#Summer SharpsCOTTON LIGHTWEIGHTS - Evening Sand - 27 Dec 2023.xlsx
# 📁 15 / 41 Processing File: KAYNAK16MANU676 INFINITY HEROES.xlsx
# 📁 16 / 41 Processing File: KAYNAK16MANU676 HEROES SOLADITE BLUE.xlsx
# 📁 17 / 41 Processing File: FRI Report - 40336409-02- Respoke Limited - PO#TAL21MANU661 - Style#Summer SharpsCOTTON LIGHTWEIGHTS - Stone - 27 Dec 2023.xlsx
# 📁 18 / 41 Processing File: FRI Report - 40336409-03 - Respoke Limited - PO#TAL21MANU661 - Style#Summer SharpsCOTTON LIGHTWEIGHTS - Evening Sand - 27 Dec 2023.xlsx
# 📁 19 / 41 Processing File: LKRWT00007464-Respoke-STAR13MANU654-DARK NAVY-StyleSHARPS SHORTS.xlsx
# 📁 20 / 41 Processing File: LKRWT00007466-Respoke-STAR13MANU654-FLINTSTONE-StyleSHARP SHORTS.xlsx
# 📁 21 / 41 Processing File: 2023_11_27_M312 Grey_RITEDU22MANU659_IR.xlsx
# 📁 22 / 41 Processing File: FRI Report - 40336409-04 - Respoke Limited - PO#TAL21MANU661 - Style#Summer SharpsCOTTON LIGHTWEIGHTS - Laurel Wreath - 27 Dec 2023.xlsx
# 📁 23 / 41 Processing File: LKRWT00007465-Respoke-STAR13MANU654-KHAKI-StyleSHARP SHORTS.xlsx
# 📁 24 / 41 Processing File: FRI Report - 40336409-05 - Respoke Limited - PO#TAL21MANU661 - Style#Summer SharpsCOTTON LIGHTWEIGHTS - Vintage Indigo - 27 Dec 2023.xlsx
# 📁 25 / 41 Processing File: RITEDU22MANU659_IR_CHAMBRAY.xlsx
# 📁 26 / 41 Processing File: FRI Report - 40336409-07 - Respoke Limited - PO#TAL21MANU661 - Style#Summer SharpsCOTTON LIGHTWEIGHTS - Lantana - 27 Dec 2023.xlsx
# 📁 27 / 41 Processing File: KAYNAK16MANU676 HEROES GRAPHITE.xlsx
# 📁 28 / 41 Processing File: 2023_11_27_RITEDU22MANU659 DARK_CHAMBRAY.xlsx
# 📁 29 / 41 Processing File: FRI Report - 40341070-04 - Respoke Limited - PO#SAITEX14MANU655 - Style#12 OZ DENIM - CHARCOAL - 24 Jan 2024.xlsx
# 📁 30 / 41 Processing File: FRI Report - 40341070-03 - Respoke Limited - PO#SAITEX14MANU655 - Style#12 OZ DENIM - OLIVE - 24 Jan 2024.xlsx
# 📁 31 / 41 Processing File: FRI Report - 40341070-02 - Respoke Limited - PO#SAITEX14MANU655 - Style#12 OZ DENIM - ECRU - 24 Jan 2024.xlsx
# 📁 32 / 41 Processing File: FRI Report - 40341070-01 - Respoke Limited - PO#SAITEX14MANU655 - Style#12 OZ DENIM - STAY BLACK  - 24 Jan 2024.xlsx
# 📁 33 / 41 Processing File: FRI Report - 40341070-05 - Respoke Limited - PO#SAITEX15MANU677 - Style#12 OZ DENIM - RINSE  - 25 Jan 2024.xlsx
# 📁 34 / 41 Processing File: FRI Report - 40341070-07 - Respoke Limited - PO#SAITEX14MANU655 - Style#12 OZ DENIM - KHAKI  - 25 Jan 2024.xlsx
# 📁 35 / 41 Processing File: FRI Report - 40341070-08 - Respoke Limited - PO#SAITEX14MANU655 - Style#12 OZ DENIM - BLACK - 25 Jan 2024.xlsx
# 📁 36 / 41 Processing File: PTR24.00071_Respoke_Lamosa_2024_02_01_Fives_Riviera_LAMOSA90MANU675_IR.xlsx
# 📁 37 / 41 Processing File: PTR24.00072.4101_RESPOKE_LAMOSA_01.02.2024_FIVES_AMMONITE_LAMOSA90MANU675_ QC.xlsx
# 📁 38 / 41 Processing File: KAYNAK17MANU682-HEROES-BLACK.xlsx
# 📁 39 / 41 Processing File: KAYNAK17MANU682-HEROES-MARS-(BRICK RED.xlsx
# 📁 40 / 41 Processing File: KAYNAK17MANU682 - HEROES - DUSTY ROSE.xlsx
# 📁 41 / 41 Processing File: KAYNAK17MANU682 - OLIVE - HEROES.xlsx

# %%
qc_files = pd.concat([qc_files_aw23, qc_files_ss24]).reset_index(drop=True)
qc_files = transform_qc_files(qc_files)

display(qc_files)
# Out:
#     inspection_type qc_provider supplier supplier_country date_of_inspection  \
# 0             FIRST          BV   KAYNAK              NaN                NaN
# 1             FIRST          BV   KAYNAK              NaN                NaN
# 2             FIRST          BV   KAYNAK              NaN                NaN
# 3             FIRST          BV   KAYNAK              NaN                NaN
# 4             FIRST          BV   KAYNAK              NaN                NaN
# ..              ...         ...      ...              ...                ...
# 240           FIRST         SGS   LAMOSA         PORTUGAL         2024-02-01
# 241           FIRST          BV   KAYNAK           TURKEY         2024-02-14
# 242           FIRST          BV   KAYNAK           TURKEY         2024-02-14
# 243           FIRST          BV   KAYNAK           TURKEY         2024-02-15
# 244           FIRST          BV   KAYNAK           TURKEY         2024-01-15
#
#            po_number garment_type         style                 colour  \
# 0    KAYNAK13MANU640     TROUSERS        HEROES    BLACK  (BLACK ONYX)
# 1    KAYNAK13MANU640     TROUSERS  HEROES TAPER    BLACK  (BLACK ONYX)
# 2    KAYNAK13MANU640     TROUSERS        HEROES  FLINTSTONE (INFINITY)
# 3    KAYNAK13MANU640     TROUSERS  HEROES TAPER  FLINTSTONE (INFINITY)
# 4    KAYNAK13MANU640     TROUSERS        HEROES       ICEBERG (QUARRY)
# ..               ...          ...           ...                    ...
# 240  LAMOSA90MANU675     TROUSERS         FIVES               AMMONITE
# 241  KAYNAK17MANU682     TROUSERS        HEROES                  BLACK
# 242  KAYNAK17MANU682     TROUSERS        HEROES       MARS (BRICK RED)
# 243  KAYNAK17MANU682     TROUSERS        HEROES             DUSTY ROSE
# 244  KAYNAK17MANU682     TROUSERS        HEROES                  OLİVE
#
#                      conform_style  ... front_length sleeve_length muscle  \
# 0    Subject to clients evaluation  ...
# 1    Subject to clients evaluation  ...
# 2    Subject to clients evaluation  ...
# 3    Subject to clients evaluation  ...
# 4    Subject to clients evaluation  ...
# ..                             ...  ...          ...           ...    ...
# 240  Subject to clients evaluation  ...
# 241                    Not Conform  ...
# 242                    Not Conform  ...
# 243                    Not Conform  ...
# 244                    Not Conform  ...
#
#     cuff_width neck_circ   qc_result  \
# 0                         INCOMPLETE
# 1                         INCOMPLETE
# 2                         INCOMPLETE
# 3                         INCOMPLETE
# 4                         INCOMPLETE
# ..         ...       ...         ...
# 240                             PASS
# 241                             PASS
# 242                             FAIL
# 243                             FAIL
# 244                             FAIL
#
#                                              file_name    folder_name  \
# 0    KAYNAK13MANU640 New Rise BLACK  (BLACK ONYX) r...  QC_files_AW23
# 1    KAYNAK13MANU640 New Rise BLACK  (BLACK ONYX) t...  QC_files_AW23
# 2    KAYNAK13MANU640 New Rise FLINTSTONE (INFINITY)...  QC_files_AW23
# 3    KAYNAK13MANU640 New Rise FLINTSTONE (INFINITY)...  QC_files_AW23
# 4    KAYNAK13MANU640 New Rise ICEBERG (QUARRY) tape...  QC_files_AW23
# ..                                                 ...            ...
# 240  PTR24.00072.4101_RESPOKE_LAMOSA_01.02.2024_FIV...  QC_files_SS24
# 241                  KAYNAK17MANU682-HEROES-BLACK.xlsx  QC_files_SS24
# 242        KAYNAK17MANU682-HEROES-MARS-(BRICK RED.xlsx  QC_files_SS24
# 243         KAYNAK17MANU682 - HEROES - DUSTY ROSE.xlsx  QC_files_SS24
# 244              KAYNAK17MANU682 - OLIVE - HEROES.xlsx  QC_files_SS24
#
#                                                file_id  \
# 0    FIRST | KAYNAK13MANU640 | HEROES | BLACK  (BLA...
# 1    FIRST | KAYNAK13MANU640 | HEROES TAPER | BLACK...
# 2    FIRST | KAYNAK13MANU640 | HEROES | FLINTSTONE ...
# 3    FIRST | KAYNAK13MANU640 | HEROES TAPER | FLINT...
# 4    FIRST | KAYNAK13MANU640 | HEROES | ICEBERG (QU...
# ..                                                 ...
# 240         FIRST | LAMOSA90MANU675 | FIVES | AMMONITE
# 241           FIRST | KAYNAK17MANU682 | HEROES | BLACK
# 242  FIRST | KAYNAK17MANU682 | HEROES | MARS (BRICK...
# 243      FIRST | KAYNAK17MANU682 | HEROES | DUSTY ROSE
# 244           FIRST | KAYNAK17MANU682 | HEROES | OLİVE
#
#                                               batch_id
# 0       KAYNAK13MANU640 | HEROES | BLACK  (BLACK ONYX)
# 1    KAYNAK13MANU640 | HEROES TAPER | BLACK  (BLACK...
# 2     KAYNAK13MANU640 | HEROES | FLINTSTONE (INFINITY)
# 3    KAYNAK13MANU640 | HEROES TAPER | FLINTSTONE (I...
# 4          KAYNAK13MANU640 | HEROES | ICEBERG (QUARRY)
# ..                                                 ...
# 240                 LAMOSA90MANU675 | FIVES | AMMONITE
# 241                   KAYNAK17MANU682 | HEROES | BLACK
# 242        KAYNAK17MANU682 | HEROES | MARS (BRICK RED)
# 243              KAYNAK17MANU682 | HEROES | DUSTY ROSE
# 244                   KAYNAK17MANU682 | HEROES | OLİVE
#
# [245 rows x 41 columns]

# %%
issues = {
    "missing_supplier": (qc_files['supplier'].isna()) | (qc_files['supplier'] == ''),
    "missing_po": (qc_files['po_number'].isna()) | (qc_files['po_number'] == ''),
    "missing_date_of_inspection": (qc_files['date_of_inspection'].isna()) | (qc_files['date_of_inspection'] == '')
          }

for issue_name, issue_logic in issues.items():
    print(f'{qc_files[issue_logic].shape[0]} files: {issue_name}')

qc_files.to_excel(f'qc_file_summaries.xlsx', index=False)
# Out:
# 20 files: missing_supplier
# 35 files: missing_po
# 50 files: missing_date_of_inspection

# %%
for issue in issues:
  display(issue, qc_files[issues[issue]])
# Out:
# 'missing_supplier'
#     inspection_type qc_provider supplier supplier_country date_of_inspection  \
# 124           FIRST         SGS      NaN          VIETNAM         2023-07-28
# 125           FIRST         SGS      NaN          VIETNAM         2023-07-28
# 126           FIRST         SGS      NaN          VIETNAM         2023-07-28
# 127           FIRST         SGS      NaN          VIETNAM         2023-07-28
# 143           FIRST         SGS      NaN          VIETNAM         2023-07-28
# 145           FIRST         SGS      NaN          VIETNAM         2023-06-26
# 151           FIRST         SGS      NaN          VIETNAM         2023-07-29
# 158           FIRST         SGS      NaN          VIETNAM         2023-06-26
# 161           FIRST         SGS      NaN          VIETNAM         2023-07-28
# 163           FIRST         SGS      NaN          VIETNAM         2023-06-19
# 168           FIRST         SGS      NaN          VIETNAM         2023-06-26
# 175           FIRST         SGS      NaN          VIETNAM         2023-06-26
# 176           FIRST         SGS      NaN          VIETNAM         2023-06-26
# 179           FIRST         SGS      NaN          VIETNAM         2023-06-26
# 192           FIRST         SGS      NaN          VIETNAM         2023-06-26
# 232           FIRST         SGS      NaN          VIETNAM         2024-01-24
# 233           FIRST         SGS      NaN          VIETNAM         2024-01-24
# 234           FIRST         SGS      NaN          VIETNAM         2024-01-24
# 235           FIRST         SGS      NaN          VIETNAM         2024-01-24
# 237           FIRST         SGS      NaN          VIETNAM         2024-01-26
#
#            po_number garment_type                                       style  \
# 124  SAITEX11MANU628     TROUSERS               12 OZ DENIM TAPER RINSE/BLACK
# 125  SAITEX11MANU628     TROUSERS                     12 OZ DENIM RINSE/BLACK
# 126  SAITEX11MANU628     TROUSERS               12 OZ DENIM TAPER RINSE/BLACK
# 127  SAITEX11MANU628     TROUSERS                     12 OZ DENIM RINSE/BLACK
# 143  SAITEX11MANU628     TROUSERS               12 OZ DENIM TAPER RINSE/BLACK
# 145  SAITEX10MANU627     TROUSERS              12 OZ DENIM BROKEN IN/CHARCOAL
# 151  SAITEX11MANU628     TROUSERS              12 OZ DENIM BROKEN IN/CHARCOAL
# 158  SAITEX10MANU627     TROUSERS               12 OZ DENIM TAPER RINSE/BLACK
# 161  SAITEX11MANU628     TROUSERS                     12 OZ DENIM RINSE/BLACK
# 163   SAITEX9MANU610     TROUSERS                            STAY BLACK DENIM
# 168  SAITEX10MANU627     TROUSERS        12 OZ DENIM TAPER BROKEN IN/CHARCOAL
# 175  SAITEX10MANU627     TROUSERS                     12 OZ DENIM RINSE/BLACK
# 176  SAITEX10MANU627     TROUSERS              12 OZ DENIM BROKEN IN/CHARCOAL
# 179  SAITEX10MANU627     TROUSERS        12 OZ DENIM TAPER BROKEN IN/CHARCOAL
# 192  SAITEX10MANU627     TROUSERS              12 OZ DENIM BROKEN IN/CHARCOAL
# 232  SAITEX14MANU655     TROUSERS  12 OZ DENIM BROKEN IN/CHARCOAL/KHAKI/OLIVE
# 233  SAITEX14MANU655     TROUSERS  12 OZ DENIM BROKEN IN/CHARCOAL/KHAKI/OLIVE
# 234  SAITEX14MANU655     TROUSERS  12 OZ DENIM BROKEN IN/CHARCOAL/KHAKI/OLIVE
# 235  SAITEX14MANU655     TROUSERS                     12 OZ DENIM RINSE/BLACK
# 237  SAITEX14MANU655     TROUSERS  12 OZ DENIM BROKEN IN/CHARCOAL/KHAKI/OLIVE
#
#          colour conform_style  ... front_length sleeve_length muscle  \
# 124       BLACK       Conform  ...
# 125       BLACK       Conform  ...
# 126       RINSE       Conform  ...
# 127       RINSE       Conform  ...
# 143       BLACK       Conform  ...
# 145   BROKEN IN       Conform  ...
# 151   BROKEN IN       Conform  ...
# 158       RINSE           NaN  ...
# 161       BLACK       Conform  ...
# 163         NaN       Conform  ...
# 168   BROKEN IN       Conform  ...
# 175       RINSE       Conform  ...
# 176   BROKEN IN       Conform  ...
# 179    CHARCOAL       Conform  ...
# 192    CHARCOAL       Conform  ...
# 232    CHARCOAL       Conform  ...
# 233       OLIVE       Conform  ...
# 234        ECRU       Conform  ...
# 235  STAY BLACK       Conform  ...
# 237       KHAKI       Conform  ...
#
#     cuff_width neck_circ qc_result  \
# 124                           PASS
# 125                           PASS
# 126                           PASS
# 127                           PASS
# 143                           PASS
# 145                           PASS
# 151                           PASS
# 158                           PASS
# 161                           PASS
# 163                           PASS
# 168                           PASS
# 175                           PASS
# 176                           PASS
# 179                           PASS
# 192                           PASS
# 232                           PASS
# 233                           PASS
# 234                           PASS
# 235                           PASS
# 237                           PASS
#
#                                              file_name    folder_name  \
# 124  FRI Report - 40311719-04 - Respoke Limited - P...  QC_files_AW23
# 125  FRI Report - 40311719-03 - Respoke Limited - P...  QC_files_AW23
# 126  FRI Report - 40311719-02 - Respoke Limited - P...  QC_files_AW23
# 127  FRI Report - 40311719-01 - Respoke Limited - P...  QC_files_AW23
# 143     SAITEX11MANU628 12 OZ DENIM TAPER - BLACK.xlsx  QC_files_AW23
# 145       SAITEX10MANU627 12 OZ DENIM - BROKEN IN.xlsx  QC_files_AW23
# 151     SAITEX11MANU628 - 12 OZ DENIM - BROKEN IN.xlsx  QC_files_AW23
# 158   SAITEX10MANU627 - 12 OZ DENIM TAPER - RINSE.xlsx  QC_files_AW23
# 161         SAITEX11MANU628 - 12 OZ DENIM - BLACK.xlsx  QC_files_AW23
# 163     SAITEX9MANU610 - 12 OZ DENIM - STAY BLACK.xlsx  QC_files_AW23
# 168  SAITEX10MANU627 - 12 OZ DENIM TAPER - BROKEN I...  QC_files_AW23
# 175         SAITEX10MANU627 - 12 OZ DENIM - RINSE.xlsx  QC_files_AW23
# 176     SAITEX10MANU627 - 12 OZ DENIM - BROKEN IN.xlsx  QC_files_AW23
# 179  SAITEX10MANU627 - 12 OZ DENIM TAPER - CHARCOAL...  QC_files_AW23
# 192      SAITEX10MANU627 - 12 OZ DENIM - CHARCOAL.xlsx  QC_files_AW23
# 232  FRI Report - 40341070-04 - Respoke Limited - P...  QC_files_SS24
# 233  FRI Report - 40341070-03 - Respoke Limited - P...  QC_files_SS24
# 234  FRI Report - 40341070-02 - Respoke Limited - P...  QC_files_SS24
# 235  FRI Report - 40341070-01 - Respoke Limited - P...  QC_files_SS24
# 237  FRI Report - 40341070-07 - Respoke Limited - P...  QC_files_SS24
#
#                                                file_id  \
# 124  FIRST | SAITEX11MANU628 | 12 OZ DENIM TAPER RI...
# 125  FIRST | SAITEX11MANU628 | 12 OZ DENIM RINSE/BL...
# 126  FIRST | SAITEX11MANU628 | 12 OZ DENIM TAPER RI...
# 127  FIRST | SAITEX11MANU628 | 12 OZ DENIM RINSE/BL...
# 143  FIRST | SAITEX11MANU628 | 12 OZ DENIM TAPER RI...
# 145  FIRST | SAITEX10MANU627 | 12 OZ DENIM BROKEN I...
# 151  FIRST | SAITEX11MANU628 | 12 OZ DENIM BROKEN I...
# 158  FIRST | SAITEX10MANU627 | 12 OZ DENIM TAPER RI...
# 161  FIRST | SAITEX11MANU628 | 12 OZ DENIM RINSE/BL...
# 163    FIRST | SAITEX9MANU610 | STAY BLACK DENIM | nan
# 168  FIRST | SAITEX10MANU627 | 12 OZ DENIM TAPER BR...
# 175  FIRST | SAITEX10MANU627 | 12 OZ DENIM RINSE/BL...
# 176  FIRST | SAITEX10MANU627 | 12 OZ DENIM BROKEN I...
# 179  FIRST | SAITEX10MANU627 | 12 OZ DENIM TAPER BR...
# 192  FIRST | SAITEX10MANU627 | 12 OZ DENIM BROKEN I...
# 232  FIRST | SAITEX14MANU655 | 12 OZ DENIM BROKEN I...
# 233  FIRST | SAITEX14MANU655 | 12 OZ DENIM BROKEN I...
# 234  FIRST | SAITEX14MANU655 | 12 OZ DENIM BROKEN I...
# 235  FIRST | SAITEX14MANU655 | 12 OZ DENIM RINSE/BL...
# 237  FIRST | SAITEX14MANU655 | 12 OZ DENIM BROKEN I...
#
#                                               batch_id
# 124  SAITEX11MANU628 | 12 OZ DENIM TAPER RINSE/BLAC...
# 125  SAITEX11MANU628 | 12 OZ DENIM RINSE/BLACK | BLACK
# 126  SAITEX11MANU628 | 12 OZ DENIM TAPER RINSE/BLAC...
# 127  SAITEX11MANU628 | 12 OZ DENIM RINSE/BLACK | RINSE
# 143  SAITEX11MANU628 | 12 OZ DENIM TAPER RINSE/BLAC...
# 145  SAITEX10MANU627 | 12 OZ DENIM BROKEN IN/CHARCO...
# 151  SAITEX11MANU628 | 12 OZ DENIM BROKEN IN/CHARCO...
# 158  SAITEX10MANU627 | 12 OZ DENIM TAPER RINSE/BLAC...
# 161  SAITEX11MANU628 | 12 OZ DENIM RINSE/BLACK | BLACK
# 163            SAITEX9MANU610 | STAY BLACK DENIM | nan
# 168  SAITEX10MANU627 | 12 OZ DENIM TAPER BROKEN IN/...
# 175  SAITEX10MANU627 | 12 OZ DENIM RINSE/BLACK | RINSE
# 176  SAITEX10MANU627 | 12 OZ DENIM BROKEN IN/CHARCO...
# 179  SAITEX10MANU627 | 12 OZ DENIM TAPER BROKEN IN/...
# 192  SAITEX10MANU627 | 12 OZ DENIM BROKEN IN/CHARCO...
# 232  SAITEX14MANU655 | 12 OZ DENIM BROKEN IN/CHARCO...
# 233  SAITEX14MANU655 | 12 OZ DENIM BROKEN IN/CHARCO...
# 234  SAITEX14MANU655 | 12 OZ DENIM BROKEN IN/CHARCO...
# 235  SAITEX14MANU655 | 12 OZ DENIM RINSE/BLACK | ST...
# 237  SAITEX14MANU655 | 12 OZ DENIM BROKEN IN/CHARCO...
#
# [20 rows x 41 columns]
# 'missing_po'
#     inspection_type qc_provider  supplier supplier_country date_of_inspection  \
# 24            FIRST         NaN  VIPALTEX              NaN                NaN
# 60            FIRST         NaN    KAYNAK              NaN                NaN
# 63            FIRST         NaN    KAYNAK              NaN                NaN
# 65            FIRST         NaN    KAYNAK              NaN                NaN
# 69            FIRST         NaN    KAYNAK              NaN                NaN
# 71            FIRST         NaN    KAYNAK              NaN                NaN
# 72            FIRST         NaN    KAYNAK              NaN                NaN
# 74            FIRST         NaN    KAYNAK              NaN                NaN
# 77            FIRST         NaN    KAYNAK              NaN                NaN
# 78            FIRST         NaN    KAYNAK              NaN                NaN
# 79            FIRST         NaN    KAYNAK              NaN                NaN
# 80            FIRST         NaN    KAYNAK              NaN                NaN
# 82            FIRST         NaN    KAYNAK              NaN                NaN
# 83            FIRST         NaN    KAYNAK              NaN                NaN
# 91            FIRST         NaN    KAYNAK              NaN                NaN
# 93            FIRST         NaN    KAYNAK              NaN                NaN
# 95            FIRST         NaN    KAYNAK              NaN                NaN
# 110           FIRST         NaN  VIPALTEX              NaN                NaN
# 111           FIRST         NaN    KAYNAK              NaN                NaN
# 112           FIRST         NaN    KAYNAK              NaN                NaN
# 117           FIRST         NaN    KAYNAK              NaN                NaN
# 118           FIRST         NaN    KAYNAK              NaN                NaN
# 119           FIRST         NaN    KAYNAK              NaN                NaN
# 120           FIRST         NaN    KAYNAK              NaN                NaN
# 121           FIRST         NaN    KAYNAK              NaN                NaN
# 122           FIRST         NaN    KAYNAK              NaN                NaN
# 123           FIRST         NaN    KAYNAK              NaN                NaN
# 196           FIRST         NaN    KAYNAK              NaN                NaN
# 197           FIRST         NaN    KAYNAK              NaN                NaN
# 198           FIRST         NaN    KAYNAK              NaN                NaN
# 199           FIRST         NaN    KAYNAK              NaN                NaN
# 200           FIRST         NaN    KAYNAK              NaN                NaN
# 201           FIRST         NaN    KAYNAK              NaN                NaN
# 202           FIRST         NaN    KAYNAK              NaN                NaN
# 203           FIRST         NaN    KAYNAK              NaN                NaN
#
#     po_number garment_type           style                    colour  \
# 24        NaN     TROUSERS  MOLESKIN FIVES                       NaN
# 60        NaN     TROUSERS    HEROES TAPER          ICEBERG (QUARRY)
# 63        NaN     TROUSERS    HEROES TAPER                     OLIVE
# 65        NaN     TROUSERS          HEROES                     OLIVE
# 69        NaN     TROUSERS    HEROES TAPER                      NAVY
# 71        NaN     TROUSERS          HEROES              HARVEST GOLD
# 72        NaN     TROUSERS    HEROES TAPER                      ONYX
# 74        NaN     TROUSERS          HEROES                     OLIVE
# 77        NaN     TROUSERS    HEROES TAPER  SMOKED NAVY (CROWN BLUE)
# 78        NaN     TROUSERS          HEROES          ICEBERG (QUARRY)
# 79        NaN     TROUSERS    HEROES TAPER                      NAVY
# 80        NaN     TROUSERS          HEROES                  AMMONITE
# 82        NaN     TROUSERS    HEROES TAPER                     OLIVE
# 83        NaN     TROUSERS          HEROES                  AMMONITE
# 91        NaN     TROUSERS    HEROES TAPER                       NaN
# 93        NaN     TROUSERS          HEROES                       NaN
# 95        NaN     TROUSERS    HEROES TAPER                       NaN
# 110       NaN     TROUSERS  MOLESKIN FIVES                       NaN
# 111       NaN     TROUSERS    HEROES TAPER                       NaN
# 112       NaN     TROUSERS          HEROES                       NaN
# 117       NaN     TROUSERS    HEROES TAPER                     OLIVE
# 118       NaN     TROUSERS    HEROES TAPER                      NAVY
# 119       NaN     TROUSERS    HEROES TAPER  SMOKED NAVY (CROWN BLUE)
# 120       NaN     TROUSERS    HEROES TAPER                      ONYX
# 121       NaN     TROUSERS          HEROES                     OLIVE
# 122       NaN     TROUSERS    HEROES TAPER          ICEBERG (QUARRY)
# 123       NaN     TROUSERS          HEROES              HARVEST GOLD
# 196       NaN     TROUSERS          HEROES                       NaN
# 197       NaN     TROUSERS    HEROES TAPER                       NaN
# 198       NaN     TROUSERS    HEROES TAPER                      NAVY
# 199       NaN     TROUSERS          HEROES                     OLIVE
# 200       NaN     TROUSERS    HEROES TAPER                       NaN
# 201       NaN     TROUSERS    HEROES TAPER                     OLIVE
# 202       NaN     TROUSERS          HEROES                  AMMONITE
# 203       NaN     TROUSERS          HEROES                       NaN
#
#                      conform_style  ... front_length sleeve_length muscle  \
# 24   Subject to clients evaluation  ...
# 60                             NaN  ...
# 63                             NaN  ...
# 65                             NaN  ...
# 69                             NaN  ...
# 71                             NaN  ...
# 72                             NaN  ...
# 74                             NaN  ...
# 77                             NaN  ...
# 78                             NaN  ...
# 79                             NaN  ...
# 80                             NaN  ...
# 82                             NaN  ...
# 83                             NaN  ...
# 91                             NaN  ...
# 93                             NaN  ...
# 95                             NaN  ...
# 110  Subject to clients evaluation  ...
# 111                            NaN  ...
# 112                            NaN  ...
# 117                            NaN  ...
# 118                            NaN  ...
# 119                            NaN  ...
# 120                            NaN  ...
# 121                            NaN  ...
# 122                            NaN  ...
# 123                            NaN  ...
# 196                            NaN  ...
# 197                            NaN  ...
# 198                            NaN  ...
# 199                            NaN  ...
# 200                            NaN  ...
# 201                            NaN  ...
# 202                            NaN  ...
# 203                            NaN  ...
#
#     cuff_width neck_circ qc_result  \
# 24                            FAIL
# 60                            FAIL
# 63                            FAIL
# 65                            FAIL
# 69                            FAIL
# 71                            FAIL
# 72                            PASS
# 74                            FAIL
# 77                            FAIL
# 78                            FAIL
# 79                            FAIL
# 80                            FAIL
# 82                            FAIL
# 83                            FAIL
# 91                            PASS
# 93                            PASS
# 95                            PASS
# 110                           FAIL
# 111                           PASS
# 112                           PASS
# 117                           FAIL
# 118                           FAIL
# 119                           PASS
# 120                           PASS
# 121                           FAIL
# 122                           PASS
# 123                           PASS
# 196                           PASS
# 197                           PASS
# 198                           FAIL
# 199                           FAIL
# 200                           PASS
# 201                           FAIL
# 202                           FAIL
# 203                           PASS
#
#                                              file_name    folder_name  \
# 24   PTR.23.00700.4101_RESPOKE_VIPALTEX_21.09.2023_...  QC_files_AW23
# 60   HEROES Taper ICEBERG (QUARRY) BV_son ölçü.xlsx  QC_files_AW23
# 63                    HEROES Taper Olive BV 16.08.xlsx  QC_files_AW23
# 65                       HEROES reg OliveBV 16.08.xlsx  QC_files_AW23
# 69                           HEROES Taper Navy BV.xlsx  QC_files_AW23
# 71                     HEROES Reg Harvest Gold BV.xlsx  QC_files_AW23
# 72               HEROES Taper Onyx BV_son ölçü.xlsx  QC_files_AW23
# 74                             HEROES reg OliveBV.xlsx  QC_files_AW23
# 77       HEROES Taper Smoked Navy (Crown Blue) BV.xlsx  QC_files_AW23
# 78     HEROES Reg ICEBERG (QUARRY) BV_son ölçü.xlsx  QC_files_AW23
# 79                     HEROES Taper Navy BV 16.08.xlsx  QC_files_AW23
# 80                   HEROES Reg Ammonite BV_16.08.xlsx  QC_files_AW23
# 82                          HEROES Taper Olive BV.xlsx  QC_files_AW23
# 83             HEROES Reg Ammonite BV_son ölçü.xlsx  QC_files_AW23
# 91                            HEROES TAPER BV (1).xlsx  QC_files_AW23
# 93                                      HEROES BV.xlsx  QC_files_AW23
# 95                                HEROES TAPER BV.xlsx  QC_files_AW23
# 110  PTR.23.00700.4101_RESPOKE_VIPALTEX_21.09.2023_...  QC_files_AW23
# 111                HEROES TAPER BV KAYNAK9MANU624.xlsx  QC_files_AW23
# 112                      HEROES BV KAYNAK9MANU624.xlsx  QC_files_AW23
# 117  KAYNAK12MANU638HEROESOLIVETAPER BV 10232212027...  QC_files_AW23
# 118  KAYNAK12MANU638 - HEROES - TAPER - NAVY 102322...  QC_files_AW23
# 119  KAYNAK12MANU638 HEROES TAPER SMOKED NAVY (CROW...  QC_files_AW23
# 120  KAYNAK12MANU638 - HEROES - ONYX - TAPER 102322...  QC_files_AW23
# 121  KAYNAK12MANU638 - HEROES - OLIVE 10232212027_M...  QC_files_AW23
# 122  KAYNAK12MANU638 - HEROES - TAPER - ICEBERG (QU...  QC_files_AW23
# 123  KAYNAK12MANU638 - HEROES - HARVEST GOLD - 1023...  QC_files_AW23
# 196                 KAYNAK 10232150763_MMT SHEET1.xlsx  QC_files_AW23
# 197                KAYNAK 10232150763_MMT SHEET 2.xlsx  QC_files_AW23
# 198             KAYNAK HEROES Taper Navy BV 16.08.xlsx  QC_files_AW23
# 199               KAYNAK HEROES reg OliveBV 16.08.xlsx  QC_files_AW23
# 200                        KAYNAK HEROES TAPER BV.xlsx  QC_files_AW23
# 201            KAYNAK HEROES Taper Olive BV 16.08.xlsx  QC_files_AW23
# 202           KAYNAK HEROES Reg Ammonite BV_16.08.xlsx  QC_files_AW23
# 203                              KAYNAK HEROES BV.xlsx  QC_files_AW23
#
#                                                file_id  \
# 24                  FIRST | nan | MOLESKIN FIVES | nan
# 60       FIRST | nan | HEROES TAPER | ICEBERG (QUARRY)
# 63                  FIRST | nan | HEROES TAPER | OLIVE
# 65                        FIRST | nan | HEROES | OLIVE
# 69                   FIRST | nan | HEROES TAPER | NAVY
# 71                 FIRST | nan | HEROES | HARVEST GOLD
# 72                   FIRST | nan | HEROES TAPER | ONYX
# 74                        FIRST | nan | HEROES | OLIVE
# 77   FIRST | nan | HEROES TAPER | SMOKED NAVY (CROW...
# 78             FIRST | nan | HEROES | ICEBERG (QUARRY)
# 79                   FIRST | nan | HEROES TAPER | NAVY
# 80                     FIRST | nan | HEROES | AMMONITE
# 82                  FIRST | nan | HEROES TAPER | OLIVE
# 83                     FIRST | nan | HEROES | AMMONITE
# 91                    FIRST | nan | HEROES TAPER | nan
# 93                          FIRST | nan | HEROES | nan
# 95                    FIRST | nan | HEROES TAPER | nan
# 110                 FIRST | nan | MOLESKIN FIVES | nan
# 111                   FIRST | nan | HEROES TAPER | nan
# 112                         FIRST | nan | HEROES | nan
# 117                 FIRST | nan | HEROES TAPER | OLIVE
# 118                  FIRST | nan | HEROES TAPER | NAVY
# 119  FIRST | nan | HEROES TAPER | SMOKED NAVY (CROW...
# 120                  FIRST | nan | HEROES TAPER | ONYX
# 121                       FIRST | nan | HEROES | OLIVE
# 122      FIRST | nan | HEROES TAPER | ICEBERG (QUARRY)
# 123                FIRST | nan | HEROES | HARVEST GOLD
# 196                         FIRST | nan | HEROES | nan
# 197                   FIRST | nan | HEROES TAPER | nan
# 198                  FIRST | nan | HEROES TAPER | NAVY
# 199                       FIRST | nan | HEROES | OLIVE
# 200                   FIRST | nan | HEROES TAPER | nan
# 201                 FIRST | nan | HEROES TAPER | OLIVE
# 202                    FIRST | nan | HEROES | AMMONITE
# 203                         FIRST | nan | HEROES | nan
#
#                                           batch_id
# 24                      nan | MOLESKIN FIVES | nan
# 60           nan | HEROES TAPER | ICEBERG (QUARRY)
# 63                      nan | HEROES TAPER | OLIVE
# 65                            nan | HEROES | OLIVE
# 69                       nan | HEROES TAPER | NAVY
# 71                     nan | HEROES | HARVEST GOLD
# 72                       nan | HEROES TAPER | ONYX
# 74                            nan | HEROES | OLIVE
# 77   nan | HEROES TAPER | SMOKED NAVY (CROWN BLUE)
# 78                 nan | HEROES | ICEBERG (QUARRY)
# 79                       nan | HEROES TAPER | NAVY
# 80                         nan | HEROES | AMMONITE
# 82                      nan | HEROES TAPER | OLIVE
# 83                         nan | HEROES | AMMONITE
# 91                        nan | HEROES TAPER | nan
# 93                              nan | HEROES | nan
# 95                        nan | HEROES TAPER | nan
# 110                     nan | MOLESKIN FIVES | nan
# 111                       nan | HEROES TAPER | nan
# 112                             nan | HEROES | nan
# 117                     nan | HEROES TAPER | OLIVE
# 118                      nan | HEROES TAPER | NAVY
# 119  nan | HEROES TAPER | SMOKED NAVY (CROWN BLUE)
# 120                      nan | HEROES TAPER | ONYX
# 121                           nan | HEROES | OLIVE
# 122          nan | HEROES TAPER | ICEBERG (QUARRY)
# 123                    nan | HEROES | HARVEST GOLD
# 196                             nan | HEROES | nan
# 197                       nan | HEROES TAPER | nan
# 198                      nan | HEROES TAPER | NAVY
# 199                           nan | HEROES | OLIVE
# 200                       nan | HEROES TAPER | nan
# 201                     nan | HEROES TAPER | OLIVE
# 202                        nan | HEROES | AMMONITE
# 203                             nan | HEROES | nan
#
# [35 rows x 41 columns]
# 'missing_date_of_inspection'
#     inspection_type qc_provider  supplier supplier_country date_of_inspection  \
# 0             FIRST          BV    KAYNAK              NaN                NaN
# 1             FIRST          BV    KAYNAK              NaN                NaN
# 2             FIRST          BV    KAYNAK              NaN                NaN
# 3             FIRST          BV    KAYNAK              NaN                NaN
# 4             FIRST          BV    KAYNAK              NaN                NaN
# 5             FIRST          BV    KAYNAK              NaN                NaN
# 6             FIRST          BV    KAYNAK              NaN                NaN
# 7             FIRST          BV    KAYNAK              NaN                NaN
# 8             FIRST          BV    KAYNAK              NaN                NaN
# 9             FIRST          BV    KAYNAK              NaN                NaN
# 10            FIRST          BV    KAYNAK              NaN                NaN
# 11            FIRST          BV    KAYNAK              NaN                NaN
# 24            FIRST         NaN  VIPALTEX              NaN                NaN
# 60            FIRST         NaN    KAYNAK              NaN                NaN
# 63            FIRST         NaN    KAYNAK              NaN                NaN
# 65            FIRST         NaN    KAYNAK              NaN                NaN
# 69            FIRST         NaN    KAYNAK              NaN                NaN
# 71            FIRST         NaN    KAYNAK              NaN                NaN
# 72            FIRST         NaN    KAYNAK              NaN                NaN
# 74            FIRST         NaN    KAYNAK              NaN                NaN
# 77            FIRST         NaN    KAYNAK              NaN                NaN
# 78            FIRST         NaN    KAYNAK              NaN                NaN
# 79            FIRST         NaN    KAYNAK              NaN                NaN
# 80            FIRST         NaN    KAYNAK              NaN                NaN
# 82            FIRST         NaN    KAYNAK              NaN                NaN
# 83            FIRST         NaN    KAYNAK              NaN                NaN
# 91            FIRST         NaN    KAYNAK              NaN                NaN
# 93            FIRST         NaN    KAYNAK              NaN                NaN
# 95            FIRST         NaN    KAYNAK              NaN                NaN
# 110           FIRST         NaN  VIPALTEX              NaN                NaN
# 111           FIRST         NaN    KAYNAK              NaN                NaN
# 112           FIRST         NaN    KAYNAK              NaN                NaN
# 117           FIRST         NaN    KAYNAK              NaN                NaN
# 118           FIRST         NaN    KAYNAK              NaN                NaN
# 119           FIRST         NaN    KAYNAK              NaN                NaN
# 120           FIRST         NaN    KAYNAK              NaN                NaN
# 121           FIRST         NaN    KAYNAK              NaN                NaN
# 122           FIRST         NaN    KAYNAK              NaN                NaN
# 123           FIRST         NaN    KAYNAK              NaN                NaN
# 193           FIRST         NaN    KAYNAK              NaN                NaN
# 194           FIRST         NaN    KAYNAK              NaN                NaN
# 195           FIRST         NaN    KAYNAK              NaN                NaN
# 196           FIRST         NaN    KAYNAK              NaN                NaN
# 197           FIRST         NaN    KAYNAK              NaN                NaN
# 198           FIRST         NaN    KAYNAK              NaN                NaN
# 199           FIRST         NaN    KAYNAK              NaN                NaN
# 200           FIRST         NaN    KAYNAK              NaN                NaN
# 201           FIRST         NaN    KAYNAK              NaN                NaN
# 202           FIRST         NaN    KAYNAK              NaN                NaN
# 203           FIRST         NaN    KAYNAK              NaN                NaN
#
#            po_number garment_type           style                    colour  \
# 0    KAYNAK13MANU640     TROUSERS          HEROES       BLACK  (BLACK ONYX)
# 1    KAYNAK13MANU640     TROUSERS    HEROES TAPER       BLACK  (BLACK ONYX)
# 2    KAYNAK13MANU640     TROUSERS          HEROES     FLINTSTONE (INFINITY)
# 3    KAYNAK13MANU640     TROUSERS    HEROES TAPER     FLINTSTONE (INFINITY)
# 4    KAYNAK13MANU640     TROUSERS          HEROES          ICEBERG (QUARRY)
# 5    KAYNAK13MANU640     TROUSERS    HEROES TAPER          MAROON (RHUBARB)
# 6    KAYNAK13MANU640     TROUSERS          HEROES      SAGE (ICEBERG GREEN)
# 7    KAYNAK13MANU640     TROUSERS    HEROES TAPER      SAGE (ICEBERG GREEN)
# 8    KAYNAK14MANU642     TROUSERS    HEROES TAPER             MEDIEVAL BLUE
# 9    KAYNAK14MANU642     TROUSERS          HEROES             MEDIEVAL BLUE
# 10   KAYNAK13MANU640     TROUSERS          HEROES          MAROON (RHUBARB)
# 11   KAYNAK13MANU640     TROUSERS          HEROES          ICEBERG (QUARRY)
# 24               NaN     TROUSERS  MOLESKIN FIVES                       NaN
# 60               NaN     TROUSERS    HEROES TAPER          ICEBERG (QUARRY)
# 63               NaN     TROUSERS    HEROES TAPER                     OLIVE
# 65               NaN     TROUSERS          HEROES                     OLIVE
# 69               NaN     TROUSERS    HEROES TAPER                      NAVY
# 71               NaN     TROUSERS          HEROES              HARVEST GOLD
# 72               NaN     TROUSERS    HEROES TAPER                      ONYX
# 74               NaN     TROUSERS          HEROES                     OLIVE
# 77               NaN     TROUSERS    HEROES TAPER  SMOKED NAVY (CROWN BLUE)
# 78               NaN     TROUSERS          HEROES          ICEBERG (QUARRY)
# 79               NaN     TROUSERS    HEROES TAPER                      NAVY
# 80               NaN     TROUSERS          HEROES                  AMMONITE
# 82               NaN     TROUSERS    HEROES TAPER                     OLIVE
# 83               NaN     TROUSERS          HEROES                  AMMONITE
# 91               NaN     TROUSERS    HEROES TAPER                       NaN
# 93               NaN     TROUSERS          HEROES                       NaN
# 95               NaN     TROUSERS    HEROES TAPER                       NaN
# 110              NaN     TROUSERS  MOLESKIN FIVES                       NaN
# 111              NaN     TROUSERS    HEROES TAPER                       NaN
# 112              NaN     TROUSERS          HEROES                       NaN
# 117              NaN     TROUSERS    HEROES TAPER                     OLIVE
# 118              NaN     TROUSERS    HEROES TAPER                      NAVY
# 119              NaN     TROUSERS    HEROES TAPER  SMOKED NAVY (CROWN BLUE)
# 120              NaN     TROUSERS    HEROES TAPER                      ONYX
# 121              NaN     TROUSERS          HEROES                     OLIVE
# 122              NaN     TROUSERS    HEROES TAPER          ICEBERG (QUARRY)
# 123              NaN     TROUSERS          HEROES              HARVEST GOLD
# 193  KAYNAK12MANU638     TROUSERS          HEROES              HARVEST GOLD
# 194  KAYNAK12MANU638     TROUSERS          HEROES          ICEBERG (QUARRY)
# 195  KAYNAK12MANU638     TROUSERS          HEROES                  AMMONITE
# 196              NaN     TROUSERS          HEROES                       NaN
# 197              NaN     TROUSERS    HEROES TAPER                       NaN
# 198              NaN     TROUSERS    HEROES TAPER                      NAVY
# 199              NaN     TROUSERS          HEROES                     OLIVE
# 200              NaN     TROUSERS    HEROES TAPER                       NaN
# 201              NaN     TROUSERS    HEROES TAPER                     OLIVE
# 202              NaN     TROUSERS          HEROES                  AMMONITE
# 203              NaN     TROUSERS          HEROES                       NaN
#
#                      conform_style  ... front_length sleeve_length muscle  \
# 0    Subject to clients evaluation  ...
# 1    Subject to clients evaluation  ...
# 2    Subject to clients evaluation  ...
# 3    Subject to clients evaluation  ...
# 4    Subject to clients evaluation  ...
# 5    Subject to clients evaluation  ...
# 6    Subject to clients evaluation  ...
# 7    Subject to clients evaluation  ...
# 8    Subject to clients evaluation  ...
# 9    Subject to clients evaluation  ...
# 10   Subject to clients evaluation  ...
# 11   Subject to clients evaluation  ...
# 24   Subject to clients evaluation  ...
# 60                             NaN  ...
# 63                             NaN  ...
# 65                             NaN  ...
# 69                             NaN  ...
# 71                             NaN  ...
# 72                             NaN  ...
# 74                             NaN  ...
# 77                             NaN  ...
# 78                             NaN  ...
# 79                             NaN  ...
# 80                             NaN  ...
# 82                             NaN  ...
# 83                             NaN  ...
# 91                             NaN  ...
# 93                             NaN  ...
# 95                             NaN  ...
# 110  Subject to clients evaluation  ...
# 111                            NaN  ...
# 112                            NaN  ...
# 117                            NaN  ...
# 118                            NaN  ...
# 119                            NaN  ...
# 120                            NaN  ...
# 121                            NaN  ...
# 122                            NaN  ...
# 123                            NaN  ...
# 193                            NaN  ...
# 194                            NaN  ...
# 195                            NaN  ...
# 196                            NaN  ...
# 197                            NaN  ...
# 198                            NaN  ...
# 199                            NaN  ...
# 200                            NaN  ...
# 201                            NaN  ...
# 202                            NaN  ...
# 203                            NaN  ...
#
#     cuff_width neck_circ   qc_result  \
# 0                         INCOMPLETE
# 1                         INCOMPLETE
# 2                         INCOMPLETE
# 3                         INCOMPLETE
# 4                         INCOMPLETE
# 5                         INCOMPLETE
# 6                         INCOMPLETE
# 7                         INCOMPLETE
# 8                         INCOMPLETE
# 9                         INCOMPLETE
# 10                        INCOMPLETE
# 11                        INCOMPLETE
# 24                              FAIL
# 60                              FAIL
# 63                              FAIL
# 65                              FAIL
# 69                              FAIL
# 71                              FAIL
# 72                              PASS
# 74                              FAIL
# 77                              FAIL
# 78                              FAIL
# 79                              FAIL
# 80                              FAIL
# 82                              FAIL
# 83                              FAIL
# 91                              PASS
# 93                              PASS
# 95                              PASS
# 110                             FAIL
# 111                             PASS
# 112                             PASS
# 117                             FAIL
# 118                             FAIL
# 119                             PASS
# 120                             PASS
# 121                             FAIL
# 122                             PASS
# 123                             PASS
# 193                             PASS
# 194                             PASS
# 195                             FAIL
# 196                             PASS
# 197                             PASS
# 198                             FAIL
# 199                             FAIL
# 200                             PASS
# 201                             FAIL
# 202                             FAIL
# 203                             PASS
#
#                                              file_name    folder_name  \
# 0    KAYNAK13MANU640 New Rise BLACK  (BLACK ONYX) r...  QC_files_AW23
# 1    KAYNAK13MANU640 New Rise BLACK  (BLACK ONYX) t...  QC_files_AW23
# 2    KAYNAK13MANU640 New Rise FLINTSTONE (INFINITY)...  QC_files_AW23
# 3    KAYNAK13MANU640 New Rise FLINTSTONE (INFINITY)...  QC_files_AW23
# 4    KAYNAK13MANU640 New Rise ICEBERG (QUARRY) tape...  QC_files_AW23
# 5    KAYNAK13MANU640 New Rise MAROON (RHUBARB) tape...  QC_files_AW23
# 6    KAYNAK13MANU640 New Rise SAGE (ICEBERG GREEN) ...  QC_files_AW23
# 7    KAYNAK13MANU640 New Rise SAGE (ICEBERG GREEN) ...  QC_files_AW23
# 8    KAYNAK14MANU642 New Rise medieval blue taper.xlsx  QC_files_AW23
# 9      KAYNAK14MANU642 New Rise medieval blue reg.xlsx  QC_files_AW23
# 10   KAYNAK13MANU640 New Rise MAROON (RHUBARB) reg....  QC_files_AW23
# 11      KAYNAK13MANU640 ICEBERG New Rise (QUARRY).xlsx  QC_files_AW23
# 24   PTR.23.00700.4101_RESPOKE_VIPALTEX_21.09.2023_...  QC_files_AW23
# 60   HEROES Taper ICEBERG (QUARRY) BV_son ölçü.xlsx  QC_files_AW23
# 63                    HEROES Taper Olive BV 16.08.xlsx  QC_files_AW23
# 65                       HEROES reg OliveBV 16.08.xlsx  QC_files_AW23
# 69                           HEROES Taper Navy BV.xlsx  QC_files_AW23
# 71                     HEROES Reg Harvest Gold BV.xlsx  QC_files_AW23
# 72               HEROES Taper Onyx BV_son ölçü.xlsx  QC_files_AW23
# 74                             HEROES reg OliveBV.xlsx  QC_files_AW23
# 77       HEROES Taper Smoked Navy (Crown Blue) BV.xlsx  QC_files_AW23
# 78     HEROES Reg ICEBERG (QUARRY) BV_son ölçü.xlsx  QC_files_AW23
# 79                     HEROES Taper Navy BV 16.08.xlsx  QC_files_AW23
# 80                   HEROES Reg Ammonite BV_16.08.xlsx  QC_files_AW23
# 82                          HEROES Taper Olive BV.xlsx  QC_files_AW23
# 83             HEROES Reg Ammonite BV_son ölçü.xlsx  QC_files_AW23
# 91                            HEROES TAPER BV (1).xlsx  QC_files_AW23
# 93                                      HEROES BV.xlsx  QC_files_AW23
# 95                                HEROES TAPER BV.xlsx  QC_files_AW23
# 110  PTR.23.00700.4101_RESPOKE_VIPALTEX_21.09.2023_...  QC_files_AW23
# 111                HEROES TAPER BV KAYNAK9MANU624.xlsx  QC_files_AW23
# 112                      HEROES BV KAYNAK9MANU624.xlsx  QC_files_AW23
# 117  KAYNAK12MANU638HEROESOLIVETAPER BV 10232212027...  QC_files_AW23
# 118  KAYNAK12MANU638 - HEROES - TAPER - NAVY 102322...  QC_files_AW23
# 119  KAYNAK12MANU638 HEROES TAPER SMOKED NAVY (CROW...  QC_files_AW23
# 120  KAYNAK12MANU638 - HEROES - ONYX - TAPER 102322...  QC_files_AW23
# 121  KAYNAK12MANU638 - HEROES - OLIVE 10232212027_M...  QC_files_AW23
# 122  KAYNAK12MANU638 - HEROES - TAPER - ICEBERG (QU...  QC_files_AW23
# 123  KAYNAK12MANU638 - HEROES - HARVEST GOLD - 1023...  QC_files_AW23
# 193           KAYNAK12MANU638 HEROES HARVEST GOLD.xlsx  QC_files_AW23
# 194       KAYNAK12MANU638 HEROES ICEBERG (QUARRY).xlsx  QC_files_AW23
# 195               KAYNAK12MANU638 HEROES AMMONITE.xlsx  QC_files_AW23
# 196                 KAYNAK 10232150763_MMT SHEET1.xlsx  QC_files_AW23
# 197                KAYNAK 10232150763_MMT SHEET 2.xlsx  QC_files_AW23
# 198             KAYNAK HEROES Taper Navy BV 16.08.xlsx  QC_files_AW23
# 199               KAYNAK HEROES reg OliveBV 16.08.xlsx  QC_files_AW23
# 200                        KAYNAK HEROES TAPER BV.xlsx  QC_files_AW23
# 201            KAYNAK HEROES Taper Olive BV 16.08.xlsx  QC_files_AW23
# 202           KAYNAK HEROES Reg Ammonite BV_16.08.xlsx  QC_files_AW23
# 203                              KAYNAK HEROES BV.xlsx  QC_files_AW23
#
#                                                file_id  \
# 0    FIRST | KAYNAK13MANU640 | HEROES | BLACK  (BLA...
# 1    FIRST | KAYNAK13MANU640 | HEROES TAPER | BLACK...
# 2    FIRST | KAYNAK13MANU640 | HEROES | FLINTSTONE ...
# 3    FIRST | KAYNAK13MANU640 | HEROES TAPER | FLINT...
# 4    FIRST | KAYNAK13MANU640 | HEROES | ICEBERG (QU...
# 5    FIRST | KAYNAK13MANU640 | HEROES TAPER | MAROO...
# 6    FIRST | KAYNAK13MANU640 | HEROES | SAGE (ICEBE...
# 7    FIRST | KAYNAK13MANU640 | HEROES TAPER | SAGE ...
# 8    FIRST | KAYNAK14MANU642 | HEROES TAPER | MEDIE...
# 9     FIRST | KAYNAK14MANU642 | HEROES | MEDIEVAL BLUE
# 10   FIRST | KAYNAK13MANU640 | HEROES | MAROON (RHU...
# 11   FIRST | KAYNAK13MANU640 | HEROES | ICEBERG (QU...
# 24                  FIRST | nan | MOLESKIN FIVES | nan
# 60       FIRST | nan | HEROES TAPER | ICEBERG (QUARRY)
# 63                  FIRST | nan | HEROES TAPER | OLIVE
# 65                        FIRST | nan | HEROES | OLIVE
# 69                   FIRST | nan | HEROES TAPER | NAVY
# 71                 FIRST | nan | HEROES | HARVEST GOLD
# 72                   FIRST | nan | HEROES TAPER | ONYX
# 74                        FIRST | nan | HEROES | OLIVE
# 77   FIRST | nan | HEROES TAPER | SMOKED NAVY (CROW...
# 78             FIRST | nan | HEROES | ICEBERG (QUARRY)
# 79                   FIRST | nan | HEROES TAPER | NAVY
# 80                     FIRST | nan | HEROES | AMMONITE
# 82                  FIRST | nan | HEROES TAPER | OLIVE
# 83                     FIRST | nan | HEROES | AMMONITE
# 91                    FIRST | nan | HEROES TAPER | nan
# 93                          FIRST | nan | HEROES | nan
# 95                    FIRST | nan | HEROES TAPER | nan
# 110                 FIRST | nan | MOLESKIN FIVES | nan
# 111                   FIRST | nan | HEROES TAPER | nan
# 112                         FIRST | nan | HEROES | nan
# 117                 FIRST | nan | HEROES TAPER | OLIVE
# 118                  FIRST | nan | HEROES TAPER | NAVY
# 119  FIRST | nan | HEROES TAPER | SMOKED NAVY (CROW...
# 120                  FIRST | nan | HEROES TAPER | ONYX
# 121                       FIRST | nan | HEROES | OLIVE
# 122      FIRST | nan | HEROES TAPER | ICEBERG (QUARRY)
# 123                FIRST | nan | HEROES | HARVEST GOLD
# 193    FIRST | KAYNAK12MANU638 | HEROES | HARVEST GOLD
# 194  FIRST | KAYNAK12MANU638 | HEROES | ICEBERG (QU...
# 195        FIRST | KAYNAK12MANU638 | HEROES | AMMONITE
# 196                         FIRST | nan | HEROES | nan
# 197                   FIRST | nan | HEROES TAPER | nan
# 198                  FIRST | nan | HEROES TAPER | NAVY
# 199                       FIRST | nan | HEROES | OLIVE
# 200                   FIRST | nan | HEROES TAPER | nan
# 201                 FIRST | nan | HEROES TAPER | OLIVE
# 202                    FIRST | nan | HEROES | AMMONITE
# 203                         FIRST | nan | HEROES | nan
#
#                                               batch_id
# 0       KAYNAK13MANU640 | HEROES | BLACK  (BLACK ONYX)
# 1    KAYNAK13MANU640 | HEROES TAPER | BLACK  (BLACK...
# 2     KAYNAK13MANU640 | HEROES | FLINTSTONE (INFINITY)
# 3    KAYNAK13MANU640 | HEROES TAPER | FLINTSTONE (I...
# 4          KAYNAK13MANU640 | HEROES | ICEBERG (QUARRY)
# 5    KAYNAK13MANU640 | HEROES TAPER | MAROON (RHUBARB)
# 6      KAYNAK13MANU640 | HEROES | SAGE (ICEBERG GREEN)
# 7    KAYNAK13MANU640 | HEROES TAPER | SAGE (ICEBERG...
# 8       KAYNAK14MANU642 | HEROES TAPER | MEDIEVAL BLUE
# 9             KAYNAK14MANU642 | HEROES | MEDIEVAL BLUE
# 10         KAYNAK13MANU640 | HEROES | MAROON (RHUBARB)
# 11         KAYNAK13MANU640 | HEROES | ICEBERG (QUARRY)
# 24                          nan | MOLESKIN FIVES | nan
# 60               nan | HEROES TAPER | ICEBERG (QUARRY)
# 63                          nan | HEROES TAPER | OLIVE
# 65                                nan | HEROES | OLIVE
# 69                           nan | HEROES TAPER | NAVY
# 71                         nan | HEROES | HARVEST GOLD
# 72                           nan | HEROES TAPER | ONYX
# 74                                nan | HEROES | OLIVE
# 77       nan | HEROES TAPER | SMOKED NAVY (CROWN BLUE)
# 78                     nan | HEROES | ICEBERG (QUARRY)
# 79                           nan | HEROES TAPER | NAVY
# 80                             nan | HEROES | AMMONITE
# 82                          nan | HEROES TAPER | OLIVE
# 83                             nan | HEROES | AMMONITE
# 91                            nan | HEROES TAPER | nan
# 93                                  nan | HEROES | nan
# 95                            nan | HEROES TAPER | nan
# 110                         nan | MOLESKIN FIVES | nan
# 111                           nan | HEROES TAPER | nan
# 112                                 nan | HEROES | nan
# 117                         nan | HEROES TAPER | OLIVE
# 118                          nan | HEROES TAPER | NAVY
# 119      nan | HEROES TAPER | SMOKED NAVY (CROWN BLUE)
# 120                          nan | HEROES TAPER | ONYX
# 121                               nan | HEROES | OLIVE
# 122              nan | HEROES TAPER | ICEBERG (QUARRY)
# 123                        nan | HEROES | HARVEST GOLD
# 193            KAYNAK12MANU638 | HEROES | HARVEST GOLD
# 194        KAYNAK12MANU638 | HEROES | ICEBERG (QUARRY)
# 195                KAYNAK12MANU638 | HEROES | AMMONITE
# 196                                 nan | HEROES | nan
# 197                           nan | HEROES TAPER | nan
# 198                          nan | HEROES TAPER | NAVY
# 199                               nan | HEROES | OLIVE
# 200                           nan | HEROES TAPER | nan
# 201                         nan | HEROES TAPER | OLIVE
# 202                            nan | HEROES | AMMONITE
# 203                                 nan | HEROES | nan
#
# [50 rows x 41 columns]

# %%
for col in qc_files.columns:
  print(col, qc_files[col].unique())
# Out:
# inspection_type ['FIRST' '' nan]
# qc_provider ['BV' 'SGS' nan '' 'TORQUE']
# supplier ['KAYNAK' 'HKS' 'IMPULSE' 'VIPALTEX' 'ECOVEST' 'LAMOSA' 'SARTIUS' 'TAL'
#  'VALERIUS' 'STAR GARMENTS' 'RITEDU' 'FAIRPLAY' 'SAITEX' nan]
# supplier_country [nan 'TURKEY' 'CHINA' 'INDIA' 'PORTUGAL' 'VIETNAM' 'SRI LANKA' 'ROMANIA']
# date_of_inspection [nan '2023-11-01' '2023-11-28' '2023-09-15' '2023-10-03' '2023-12-05'
#  '2023-10-11' '2023-10-10' '2023-10-24' '2023-09-21' '2023-09-19'
#  '2023-09-11' '2023-09-28' '2023-09-27' '2023-09-18' '2023-09-14'
#  '2023-09-06' '2023-09-05' '2023-09-04' '2023-08-06' '2023-08-07'
#  '2023-08-09' '2023-08-10' '2023-08-04' '2023-07-31' '2023-08-03'
#  '2023-12-09' '2023-12-28' '2023-10-25' '2023-07-28' '2024-02-07'
#  '2023-07-05' '2023-07-10' '2023-06-30' '2023-03-30' '2023-07-11'
#  '2023-04-27' '2023-06-26' '2023-07-29' '2023-05-31' '2023-06-19'
#  '2023-07-12' '2023-10-18' '2023-09-13' '2023-10-19' '2023-10-20'
#  '2024-01-10' '2024-01-05' '2023-12-30' '2023-12-27' '2023-12-26'
#  '2023-12-22' '2023-11-27' '2024-01-24' '25-01-2024' '2024-01-26'
#  '2024-01-25' '2024-02-01' '2024-02-14' '2024-02-15' '2024-01-15']
# po_number ['KAYNAK13MANU640' 'KAYNAK14MANU642' 'HKS2MANU684' 'IMPULSE13MANU607'
#  'VIPALTEX1MANU648' 'ECOVEST2MANU700' 'LAMOSA69MANU630' nan
#  'ECOVEST1MANU595' 'ECOVESTT1MANU595' 'KAYNAK15MANU658' 'LAMOSA70MANU637'
#  'SARTIUS22MANU643' 'LAMOSA67MANU617' 'IMPULSE15MANU629' 'TAL17MANU636'
#  'VALERIUS62MANU641' 'STAR10MANU625' 'RUTEDU20MANU620' 'LAMOSA68MANU618'
#  'RITEDU20MANU620' 'VALERIUS65MANU647' 'RITEDU19MANU619' 'RUTEDU19MANU619'
#  'FAIRPLAY67MANU626' 'SAITEX13MANU649' 'SAITEX12MANU639' 'STAR9MANU614'
#  'SAITEX11MANU628' 'IMPULSE1MAN604' 'IMPULSE11MANU605' 'IMPULSE12MANU606'
#  'RITEDU18MANU608' 'RUTEDU18MANU608' 'LAMOSA64MANU568' 'SAITEX10MANU627'
#  'IMPULSE11MANU606' 'IMPULSE10MANU604' 'IMPULSE10MAN604' 'SAITEX9MANU610'
#  'FAIRPLAY69MANU633' 'FAIRPLAY70MANU644' 'FAIRPLAY65MANU591'
#  'FAIRPLAY68MANU632' 'KAYNAK12MANU638' 'VALERIUS67MANU670'
#  'LAMOSA90MANU675' 'STAR14MANU668' 'LAMOSA80MANU670' 'STAR13MANU654'
#  'STAR11MANU652' 'TAL21MANU661' 'KAYNAK16MANU676' 'RITEDU22MANU659'
#  'SAITEX14MANU655' 'SAITEX15MANU677' 'KAYNAK17MANU682']
# garment_type ['TROUSERS' 'TOPS' 'BOXERS']
# style ['HEROES' 'HEROES TAPER' 'CASHMERE HALF ZIP' 'WINTER HEROES'
#  'HEAVY T-SHIRT' 'BOXERS' 'CORD FIVES' 'MOLESKIN FIVES' 'WINTER SMARTS'
#  'SANTA PANT' 'SHARPS' 'LONG SLEEVE T-SHIRT' 'CASHMERE SHARPS'
#  'CORD SHARPS' 'VELVET SHARPS' 'CORD SHIRT' 'T-SHIRT' 'OXFORD SHIRT'
#  'ITALIAN DENIM 7 YEAR WASH' '12 OZ DENIM BROKEN IN/CHARCOAL/KHAKI/OLIVE'
#  'SHARPS TAPER' '12 OZ DENIM TAPER RINSE/BLACK' '12 OZ DENIM RINSE/BLACK'
#  'NANTUCKET FIVES' '12 OZ DENIM BROKEN IN/CHARCOAL' 'BULLETPROOFS'
#  'STAY BLACK DENIM' '12 OZ DENIM TAPER BROKEN IN/CHARCOAL'
#  'HEMP DENIM BROKEN IN' 'HEMP DENIM RINSE'
#  'TRAVEL DENIM BROKEN IN/CHARCOAL' 'TRAVEL DENIM RINSE/BLACK'
#  'BRETON SS T SHIRT' 'FIVES' 'PLEATE FRONT WIDE LEG' 'SHARP SHORTS'
#  'ELASTICATED WAIST' 'COTTON LIGHTWEIGHTS']
# colour ['BLACK  (BLACK ONYX)' 'FLINTSTONE (INFINITY)' 'ICEBERG (QUARRY)'
#  'MAROON (RHUBARB)' 'SAGE (ICEBERG GREEN)' 'MEDIEVAL BLUE' 'KHAKI' 'NAVY'
#  'BITTER CHOCOLATE' 'WHITE' 'GREY MARL' 'SCARAB' nan 'OATMEAL' 'GRISAILLE'
#  'BLACK' 'CARAMEL (CARAMEL CAFÉ)' 'FOREST (SCARAB)' 'IVY GREEN' 'FAWN'
#  'FEATHER GREY' 'BLUE HERRINGBONE' 'BRICK RED' 'RED' 'CROWN BLUE'
#  'DARK NAVY' 'INFINITY' 'GRAPHITE' 'DEEP FOREST' 'BEECH'
#  'NOCTURNE (VINTAGE INDIGO)' 'THUNDER (STORMY WEATHER)' 'QUARRY' 'OLIVE'
#  'COFFEE BEAN' 'HARVEST GOLD' 'ONYX' 'BIRCH' 'SMOKED NAVY (CROWN BLUE)'
#  'AMMONITE' 'MULBERRY (TAWNY)' 'CARAMEL CAFÉ' 'DEEP SPACE' 'MAUVE SHADOWS'
#  'GREEN GABLES' 'MARRON CHECK' 'TAWNY PORT' 'STONE' 'RHUBARB' '7YEAR'
#  'DIJON' 'BROKEN IN' 'CHARCOAL' 'RINSE' 'FOREST' 'DARK CHAMBRAY' 'SKY'
#  'SKY CAPTAIN' 'AMMONOITE' 'BLACK ONYX' 'LEAD' 'AQUA GREY' 'QUIET SHADE'
#  'ITALIAN DENIM HEROES RINSE WASH' 'INDIGO' '5YEAR' 'INDINGO'
#  'INSIGNIA/BLUE' 'LAUREL' 'LAUREL WREATH' 'SEPIA TINT' 'ASHLEY BLUE'
#  'ARGAN OIL' 'PERISCOPE/ECRU' 'EVENING SAND' 'SOLADITE BLUE' 'FLINTSTONE'
#  'GREY' 'VINTAGE INDIGO' 'CHAMBRAY' 'LANTANA' 'ECRU' 'STAY BLACK'
#  'RIVIERA' 'MARS (BRICK RED)' 'DUSTY ROSE' 'OLİVE']
# conform_style ['Subject to clients evaluation' 'Conform' '' nan 'Not Conform']
# conform_packing ['Conform' '' 'Subject to clients evaluation' 'Not Conform' nan]
# conform_label ['Conform' '' 'Subject to clients evaluation' 'Not Conform' nan]
# conform_odour ['Conform' '' nan]
# order_qty [420 180 385 139 135 100 292 108 300 276 365 120 430 800 637 770 215 500
#  400 1500 482 524 37 nan 1200 421 600 277 1276 200 363 302 151 98 449 1078
#  291 781 409 1219 201 399 518 150 2200 275 725 450 702 900 525 174 635
#  '400 PIECES' 1298 194 373 227 1000 206 562 796 387]
# qty_declared ['' '121' '326' '296' '299' '179' '120' '583' '180' '844' '301' '637'
#  '123' '734' '330' '226' '407' '399' '177' '745' '337' '338' '376' '306'
#  '315' '269' '542' '1468' '564' '502' '527' '331' '397' '395' '334' '345'
#  '336' '638' '312' '497' '79' '1303' '421' '300' '282' '1343' '318' '209'
#  '363' '200' '321' '415' '522' '785' '468' '314' '233' '311' '535' '517'
#  '283' '307' '648' '393' '291' '151' '106' '452' '1123' '305' '767' '454'
#  '1176' '416' '539' '322' '162' '2207' '277' '764' '310' '316' '603' '500'
#  '558' '119' '630' '735' '792' '949' '545' '176' '662' '287' '430' '414'
#  '1352' '114' '381' '201' '391' '605' '448' '231' '489' '1050' '1017'
#  '213' '327' '1240' '494' '474' '480' '303' '218' '320' '332' '487' '493'
#  '976' '1009' '295' '1010' '302' '923' '529' '304' '820' '403' '396' '987'
#  '606' '215' '983']
# qty_packed ['' '121' '326' '240' '299' '179' '120' '583' '180' '844' '301' '637'
#  '123' '734' '330' '226' '407' '399' '177' '0' '338' '376' '542' '1468'
#  '564' '502' '527' '269' '331' '397' '395' '334' '345' '336' '524' '312'
#  '497' '79' '1303' '300' '282' '1343' '318' '209' '321' '415' '522' '785'
#  '468' '200' '314' '233' '311' '535' '517' '283' '307' '296' '648' '393'
#  '291' '151' '106' '452' '1123' '305' '767' '454' '1176' '12' '416' '539'
#  '162' '2207' '277' '764' '310' '316' '603' '500' '558' '119' '630' '735'
#  '792' '949' '545' '176' '35' '287' '430' '414' '1352' '114' '24' '11'
#  '391' '605' '448' '231' '489' '315' '1050' '1017' '213' '327' '494' '474'
#  '480' '303' '218' '320' '332' '487' '493' '976' '1009' '295' '1010' '421'
#  '302' '923' '529' '304' '820' '403' '987' '606' '215' '983']
# units_inspected [nan 20 50 32 80 125 22 21 38 39 75 30 58 630 95 '80 PCS' '50 PIECES' 62
#  18]
# units_measured [nan 20 50 32 80 1 46 125 48 22 21 38 39 75 330 33 81 30 58 95 '50 PIECES'
#  62 124 18 37]
# units_rejected_measurement [ 2 14  1  0 10  3  5  6  4 12  7  8 13 19]
# units_rejected_quality [ 0  1  7  2  3  8 10  6  5  4 11 19 13 12  9]
# units_rejected_quality_major [ 0  3  1  2  7  4  5 16  6]
# units_rejected_quality_minor [0 1 4 2 6 5 3 7 8]
# units_rejected_quality_critical [0]
# waist [ 0  1  8 10  2  3  6  5  4]
# hip [0 1 2 '' 4 5 3 8 12 9]
# front_rise [0 4 2 1 '' 6 3]
# back_rise [0 3 1 2 5 '']
# thigh [2 14 0 3 1 6 4 '' 5 34 27]
# knee [0 2 1 '' 3 14 17 9]
# hem [0 '' 1]
# chest ['' 0 1 10 13]
# front_length ['' 0 1]
# sleeve_length ['' 0 1]
# muscle ['' 0 9 2]
# cuff_width ['' 0 8 1 10]
# neck_circ ['' 1 0 2]
# qc_result ['INCOMPLETE' 'FAIL' 'PASS' 'Subject to client decision'
#  'Subject to clients evaluation' 'Conform' 'Subject to client decision '
#  'Subjecto to client decision']
# file_name ['KAYNAK13MANU640 New Rise BLACK  (BLACK ONYX) reg.xlsx'
#  'KAYNAK13MANU640 New Rise BLACK  (BLACK ONYX) taper.xlsx'
#  'KAYNAK13MANU640 New Rise FLINTSTONE (INFINITY) reg.xlsx'
#  'KAYNAK13MANU640 New Rise FLINTSTONE (INFINITY) taper.xlsx'
#  'KAYNAK13MANU640 New Rise ICEBERG (QUARRY) taper.xlsx'
#  'KAYNAK13MANU640 New Rise MAROON (RHUBARB) taper.xlsx'
#  'KAYNAK13MANU640 New Rise SAGE (ICEBERG GREEN) reg.xlsx'
#  'KAYNAK13MANU640 New Rise SAGE (ICEBERG GREEN) taper.xlsx'
#  'KAYNAK14MANU642 New Rise medieval blue taper.xlsx'
#  'KAYNAK14MANU642 New Rise medieval blue reg.xlsx'
#  'KAYNAK13MANU640 New Rise MAROON (RHUBARB) reg.xlsx'
#  'KAYNAK13MANU640 ICEBERG New Rise (QUARRY).xlsx'
#  'KAYNAK13MANU640 New Rise KHAKI TAPER.xlsx'
#  'KAYNAK13MANU640 New Rise KHAKI REG.xlsx'
#  'HKS2MANU684 NAVY STRAIGHT.xlsx'
#  'BLRWT00002174_RESPOKE-IMPULSE_PO_IMPULSE13MANU607_BITTER CHOCOLATE_WINTER HEROES_MMT (1).xlsx'
#  'PTR23.00752.4101_RESPOKE_VIPALTEX_VIPALTEX1MANU648_HEAVYSHIRT_WHITE_3_OCT.xlsx'
#  'PTR23.00753.4101_RESPOKE_VIPALTEX_VIPALTEX1MANU648_HEAVYSHIRT_NAVY_3_Oct.xlsx'
#  'HKS2MANU684 SLIM GREY MARL.xlsx'
#  'PO-HKS2MANU684 STRAIGHT GREY MARL.xlsx'
#  'PTR23.00966_RESPOKE_ECOVESTE_2023_12_05_ BOXERS LEG LENGTH 3_ ECOVEST2MANU700.xlsx'
#  'HKS2MANU684 NAVY SLIM.xlsx'
#  'PTR23.00773_RESPOKE_LAMOSA_2023_10_11_ FIVES CORD NAVY_ LAMOSA69MANU630.xlsx'
#  'PTR.23.00755.4101_RESPOKE_VIPALTEX_03.10.2023_HEAVY T-SHIRT_SCARAB_VIPALTEX1MANU648_ QC.xlsx'
#  'PTR.23.00700.4101_RESPOKE_VIPALTEX_21.09.2023_HEAVY T-SHIRT_NAVY_VIPALTE....xlsx'
#  'ECOVEST_05.12.2023_BOXERS_NAVY_ECOVEST2MANU700_ QC.xlsx'
#  'HKS2 OATMEAL STRAIGHT.xlsx'
#  'PTR23.00781.4101_RESPOKE_ECOVEST_2023_10_11_ ECOVESTT1MANU596_1R_ NAVY.xlsx'
#  'PTR23.00777.4101_RESPOKE_LAMOSA_LAMOSA69MANU630_.CORD FIVES_GRISAILLE_10_10.xlsx'
#  'PTR23.00780.4101_RESPOKE_ ECOVEST_2023_10_11_ECOVESTT1MANU595_IR_BLACK.xlsx'
#  'KAYNAK15MANU658 - CARAMEL (CARAMEL CAFÉ).xlsx'
#  'PTR23.00783.4101_RESPOKE_ECOVEST_BOXERS_BLACK_11_10_ECOVESTT1MANU596_1R.xlsx'
#  'KAYNAK15MANU658 - FOREST (SCARAB).xlsx'
#  'PTR23.00772_RESPOKE_LAMOSA_2023_10_10_ FIVES CORD IVY GREEN_ LAMOSA70MANU637.xlsx'
#  'BLRWT00002174_RESPOKE-IMPULSE_PO_IMPULSE13MANU607_BITTER CHOCOLATE_WINTER HEROES_MMT.xlsx'
#  'HKS2 OATMEAL SLIM.xlsx'
#  'PTR23.00779.4101_RESPOKE_LAMOSA _ 2023_10_10_MANU 69MANU630_FAWN_IR.xlsx'
#  'PTR23.00701.4101_RESPOKE_VIPALTEX_VIPALTEX1MANU648_HEAVYSHIRT_WHITE.xlsx'
#  'PTR23.00776.4101_RESPOKE_LAMOSA_LAMOSA69MANU630_CORD FIVES_FEATHER GREY_10_10.xlsx'
#  'PTR23.00784.4101_RESPOKE_ECOVEST_BOXERS_SCARAB_11_10_ECOVESTT1MANU596_1R.xlsx'
#  'PTR23.00701.4101_RESPOKE_VIPALTEX_VIPALTEX1MANU648_HEAVYSHIRT_WHITE (1).xlsx'
#  'PTR23.00687_Respoke_Sartius_2023_09_19_Winter Smarts_Blue Herringbone_SARTIUS22MANU643_IR.xlsx'
#  'PTR23.00670.4101_RESPOKE_LAMOSA_11_09_2023_LAMOSA67MANU617_Trousers_Brick_Red.xlsx'
#  'PTR23.00686_Respoke_Sartius_2023_09_19_Santa Pant_Red_SARTIUS22MANU643_IR.xlsx'
#  'BLRWT00002215_RESPOKE-IMPULSE_PO_IMPULSE15MANU629_CROWN BLUE_HEROES_MMT.xlsb'
#  'BLRWT00002171_RESPOKE-IMPULSE_PO_IMPULSE13MANU607_DARK NAVY_WINTER HEROES_MMT.xlsx'
#  'BLRWT00002211_RESPOKE-IMPULSE_PO_IMPULSE15MANU629_BLACK ONYX_HEROES_MMT.xlsb'
#  'BLRWT00002216_RESPOKE-IMPULSE_PO_IMPULSE15MANU629_GRAPHITE_HEROES TAPER_MMT.xlsb'
#  'BLRWT00002172_RESPOKE-IMPULSE_PO_IMPULSE13MANU607_DEEP FOREST_WINTER HEROES_MMT.xlsx'
#  'PTR.23.00700.4101_RESPOKE_VIPALTEX_21.09.2023_HEAVY T-SHIRT_SCARAB_VIPALTEX1MANU648_ QC (1).xlsx'
#  'BLRWT00002173_RESPOKE-IMPULSE_PO_IMPULSE13MANU607_BEECH_WINTER HEROES_MMT (1).xlsx'
#  'PTR.23.00700.4101_RESPOKE_VIPALTEX_21.09.2023_HEAVY T-SHIRT_SCARAB_VIPALTEX1MANU648_ QC.xlsx'
#  'FRI Report - 40317390-02 - Respoke Limited - PO#TAL17MANU636 - Style#TRAVEL SHARPS - VINTAGE INDIGO - 18 Sep 2023.xlsx'
#  'BLRWT00002173_RESPOKE-IMPULSE_PO_IMPULSE13MANU607_BEECH_WINTER HEROES_MMT.xlsx'
#  'FRI Report - 40317390-01- Respoke Limited - PO#TAL17MANU636 - Style#TRAVEL SHARPS - STORMY WEATHER- 18 Sep 2023.xlsx'
#  'PTR23.00679.4101_RESPOKE_VALERIUS_2023_09_14_VALERIUS62MANU641_IR_QUARRY.xlsx'
#  'PTR23.00677.4101_RESPOKE_VALERIUS_14_09_VALERIUS62MANU641_LSTHIRT_NAVY.xlsx'
#  'PTR23.00702.4101_RESPOKE_VIPALTEX_VIPALTEX1MANU648_HEAVYSHIRT_NAVY.xlsx'
#  'PTR23.00678.4101_RESPOKE_VALERIUS_2023_09_14_VALERIUS62MANU641_IR_ WHITE.xlsx'
#  'BLRWT00002212_RESPOKE-IMPULSE_PO_IMPULSE15MANU629_INFINITY_HEROES TAPER_MMT.xlsb'
#  'HEROES Taper ICEBERG (QUARRY) BV_son ölçü.xlsx'
#  'LKRWT00006830-STAR10MANU625-Style_CAHMERE SHARPS.xlsx'
#  'LKRWT00006810_STAR10MANU625_Style-CORD SHARPS.xlsx'
#  'HEROES Taper Olive BV 16.08.xlsx'
#  'BLRWT00002210_RESPOKE-IMPULSE_PO_IMPULSE15MANU629_OLIVE_HEROES TAPER_MMT.xlsb'
#  'HEROES reg OliveBV 16.08.xlsx'
#  'PTR23.00671.4101_RESPOKE_LAMOSA_11.09.2023_MOLESKIN FIVES_COFFEE BEAN_LAMOSA67MANU617 (2).xlsx'
#  'LKRWT00006831-STAR10MANU625-Style_CASHMERESHARPS.xlsx'
#  'LKRWT00006809_STAR10MANU625_Style-CORD SHARPS.xlsx'
#  'HEROES Taper Navy BV.xlsx'
#  'BLRWT00002209_RESPOKE-IMPULSE_PO_IMPULSE15MANU629_NAVY_HEROES_MMT.xlsb'
#  'HEROES Reg Harvest Gold BV.xlsx' 'HEROES Taper Onyx BV_son ölçü.xlsx'
#  'LKRWT00006807-STAR10MANU625-Style-VELVET SHARPS.xlsx'
#  'HEROES reg OliveBV.xlsx'
#  'BLRWT00002210_RESPOKE-IMPULSE_PO_IMPULSE15MANU629_OLIVE_HEROES_MMT.xlsb'
#  'PTR23.00609.4101_RESPOKE_RITEDU_07_08_2023_ RITEDU20MANU620_BIRCH_IR...xlsx'
#  'HEROES Taper Smoked Navy (Crown Blue) BV.xlsx'
#  'HEROES Reg ICEBERG (QUARRY) BV_son ölçü.xlsx'
#  'HEROES Taper Navy BV 16.08.xlsx' 'HEROES Reg Ammonite BV_16.08.xlsx'
#  'LKRWT00006808_STAR10MANU625_Style-VELVET SHARPS.xlsx'
#  'HEROES Taper Olive BV.xlsx' 'HEROES Reg Ammonite BV_son ölçü.xlsx'
#  'PTR23. 00613.4101_RESPOKE_LAMOSA _2023_08_07_LAMOSA68MANU618_IR_ BLACKEND PEARL.xlsx'
#  'PTR23. 00612.4101_RESPOKE_LAMOSA _2023_08_07_LAMOSA68MANU618_IR_ CARAMEL CAFÉ.xlsx'
#  'PTR23.00622_Respoke_Lamosa_2023_08_09_Moleskin Fives_Deep Space_LAMOSA67MANU617_IR.xlsx'
#  'PTR23.00623_Respoke_Lamosa_2023_08_10_Moleskin Fives_Ivy Green_LAMOSA67MANU617_IR.xlsx'
#  'PTR23.00607.4101_RESPOKE_RITEDU_31_07_2023_ RITEDU20MANU620_SCRAB_IR....xlsx'
#  'PTR23.00604_Respoke_Ritedu_2023_08_04_Cord Shirt_Dark Navy_RITEDU20MANU620_IR.xlsx'
#  'PTR23.00608.4101_RESPOKE_RITEDU_04_08_2023_ RITEDU20MANU620_MAUVE SHADOWS_IR....xlsx'
#  'HEROES TAPER BV (1).xlsx'
#  'PTR23.00624_RESPOKE_LAMOSA_2023_08_09_ Moleskin Fives_Harvest Gold_ LAMOSA67MANU617.xlsx'
#  'HEROES BV.xlsx'
#  'PTR23.00599_RESPOKE_VALERIUS_2023_08_04_VALERIUS65MANU647_TSHIRT_GREEN GABLES.xlsx'
#  'HEROES TAPER BV.xlsx'
#  'PTR23.00603_RESPOKE_LAMOSA_2023_08_06_ FIVES CORD IVY GREEN_ LAMOSA68MANU618_IR.xlsx'
#  'PTR23.00581.4101_RESPOKE_RITEDU_2023_07_31_RITEDU19MANU619_MARRON CHECK _IR.xlsx'
#  'PTR23.00605_Respoke_Ritedu_2023_08_04_Cord Shirt_Tawny Port_RITEDU20MANU620_IR.xlsx'
#  'PTR23.00580.4101_RESPOKE_RITEDU_31_07_2023_ RITEDU19MANU619_STONE_IR.xlsx'
#  'PTR23.00579.4101_RESPOKE_RITEDU_31_07_2023_ RITEDU19MANU619_OLIVE_IR.xlsx'
#  'PTR23.00598_RESPOKE_VALERIUS_2023_08_03_VALERIUS65MANU647_TSHIRT_RHUBARB.xlsx'
#  '12.09 ITALIAN DENIM 7YEARS.xlsx'
#  'FRI Report - 40337174-02 - Respoke Limited - PO#SAITEX13MANU649 - Style#HEROES - DIJON - 28 DEC 2023.xlsx'
#  'FRI Report - 40337174-04 - Respoke Limited - PO#SAITEX13MANU649 - Style#HEROES TAPER - COFFEE BEAN - 28 DEC 2023.xlsx'
#  'FRI Report - 40337174-03 - Respoke Limited - PO#SAITEX13MANU649 - Style#HEROES TAPER - DIJON - 28 DEC 2023.xlsx'
#  'FRI Report - 40337174-01 - Respoke Limited - PO#SAITEX13MANU649 - Style#HEROES - COFFEE BEAN  - 28 DEC 2023.xlsx'
#  'FRI Report - 40319298-01 - Respoke Limited - PO#SAITEX12MANU639 - Style#12 OZ DENIM - BROKEN IN  - 19 Sep 2023 (1).xlsx'
#  'FRI Report - 40319298-01 - Respoke Limited - PO#SAITEX12MANU639 - Style#12 OZ DENIM - BROKEN IN  - 19 Sep 2023 (2).xlsx'
#  'FRI Report - 40319298-01 - Respoke Limited - PO#SAITEX12MANU639 - Style#12 OZ DENIM - BROKEN IN  - 19 Sep 2023.xlsx'
#  'PTR.23.00700.4101_RESPOKE_VIPALTEX_21.09.2023_HEAVY T-SHIRT_SCARAB_VIPAL....xlsx'
#  'HEROES TAPER BV KAYNAK9MANU624.xlsx' 'HEROES BV KAYNAK9MANU624.xlsx'
#  'LKRWT00007097_STAR9MANU614_SHARPS TAPER (1).XLSX'
#  'LKRWT00007096_STAR9MANU614_SHARPS TAPER (1).xlsx'
#  'LKRWT00007107_STAR9MANU614_SHARPS (1).xlsx'
#  'LKRWT00007106_STAR9MANU614-_SHARPS .XLSX'
#  'KAYNAK12MANU638HEROESOLIVETAPER BV 10232212027_MMT3.xlsx'
#  'KAYNAK12MANU638 - HEROES - TAPER - NAVY 10232212027_MMT4.xlsx'
#  'KAYNAK12MANU638 HEROES TAPER SMOKED NAVY (CROWN BLU)10232212027_MMT1.xlsx'
#  'KAYNAK12MANU638 - HEROES - ONYX - TAPER 10232212027_MMT2.xlsx'
#  'KAYNAK12MANU638 - HEROES - OLIVE 10232212027_MMT6.xlsx'
#  'KAYNAK12MANU638 - HEROES - TAPER - ICEBERG (QUARRY) 10232212027_MMT5.xlsx'
#  'KAYNAK12MANU638 - HEROES - HARVEST GOLD - 10232212027_MMT8.xlsx'
#  'FRI Report - 40311719-04 - Respoke Limited - PO#SAITEX11MANU628 - Style#12 OZ DENIM TAPER - BLACK - 28-Jul-2023 (1).xlsx'
#  'FRI Report - 40311719-03 - Respoke Limited - PO#SAITEX11MANU628 - Style#12 OZ DENIM - BLACK - 28-Jul-2023.xlsx'
#  'FRI Report - 40311719-02 - Respoke Limited - PO#SAITEX11MANU628 - Style#12 OZ DENIM TAPER - RINSE - 28-Jul-2023.xlsx'
#  'FRI Report - 40311719-01 - Respoke Limited - PO#SAITEX11MANU628 - Style#12 OZ DENIM - RINSE - 28-Jul-2023.xlsx'
#  'PTR24.00088.4101_RESPOKE_ECOVEST_BOXERS 3IN_SCARAB_ECOVEST2MANU700_2024 QC MASTER FILE.xlsx'
#  'PTR24.00089.4101_RESPOKE_ECOVEST_BOXERS 5IN_SCARAB_ECOVEST2MANU700_2024 QC MASTER FILE.xlsx'
#  'IMPULSE1MANU604 HEROES TAPER AMMONITE.xlsx'
#  'IMPULSE11MANU605 HEROES TAPER INFINITY.xlsx'
#  'IMPULSE12MANU606_NAVY_HEROES _MMT.xlsx'
#  'RITEDU18MANU608_OXFORD SHIRT_GREY MARL_IR 2.xlsx'
#  'RITEDU18MANU608_OXFORD SHIRT_GREY MARL_IR.xlsx'
#  'IMPULSE11MANU605 HEROES TAPER OLIVE.xlsx'
#  'IMPULSE11MANU605 HEROES REG OLIVE.xlsx'
#  'RITEDU18MANU608_ IR DARK_CAMBRAY.xlsx'
#  'RITEDU18MANU608_ IR CAMBRAY.xlsx' 'RITEDU18MANU608_WHITE_IR.xlsx'
#  'IMPULSE11MANU605 HEROES INFINITY.xlsx'
#  'RITEDU18MANU608 OXFORD SHIRT_SKY_IR.xlsx'
#  'IMPULSE12MANU606 HEROES TAPER GRAPHITE.xlsx'
#  'SAITEX11MANU628 12 OZ DENIM TAPER - BLACK.xlsx'
#  'LAMOSA64MANU568 NANTUCKET_SKY CAPTAIN.xlsx'
#  'SAITEX10MANU627 12 OZ DENIM - BROKEN IN.xlsx'
#  'IMPULSE12MANU606 HEROES GRAPHITE.xlsx'
#  'IMPULSE11MANU605_INFINITY_HERO_HEROES TAPER_MMT_Regular.xlsx'
#  'IMPULSE11MANU606_NAVY_HEROES TAPER_MMT 2.xlsx'
#  'IMPULSE11MANU606_NAVY_HEROES TAPER_MMT.xlsx'
#  'IMPULSE10MANU604_AMMONITE_HERO_HEROES TAPER_MMT_Regular.xlsx'
#  'SAITEX11MANU628 - 12 OZ DENIM - BROKEN IN.xlsx'
#  'IMPULSE10MANU604_AMMONITE_HERO_HEROES TAPER_MMT_Taper.xlsx'
#  'IMPULSE11MANU605_INFINITY_HERO_HEROES TAPER_MMT_Taper.xlsx'
#  'IMPULSE12MANU606_GRAPHITE_HEROES TAPER.xlsx'
#  'IMPULSE11MANU606 HEROES TAPER NAVY.xlsx'
#  'IMPULSE10MAN604 HEROES TAPER AMMONITE.xlsx'
#  'LAMOSA64MANU568 Bulletproofs_Black Onyx.xlsx'
#  'SAITEX10MANU627 - 12 OZ DENIM TAPER - RINSE.xlsx'
#  'LAMOSA64MANU568 NANTUCKET_LEAD.xlsx'
#  'IMPULSE11MANU605 HEROES TAPER INFINITY 2.xlsx'
#  'SAITEX11MANU628 - 12 OZ DENIM - BLACK.xlsx'
#  'STAR9MANU614_SHARPS TAPER DARK NAVY.xlsx'
#  'SAITEX9MANU610 - 12 OZ DENIM - STAY BLACK.xlsx'
#  'IMPULSE12MANU606 - HEROES Taper Graphite.xlsx'
#  'STAR9MANU614 - SHARPS DARK NAVY.xlsx'
#  'LAMOSA64MANU568 NANTUCKET FIVES _AQUA GREY.xlsx'
#  'IMPULSE11MANU605_SCARAB_HERO.xlsx'
#  'SAITEX10MANU627 - 12 OZ DENIM TAPER - BROKEN IN.xlsx'
#  'STAR9MANU614_SHARPS CHARCOAL.xlsx'
#  'IMPULSE12MANU606_GRAPHITE_HERO_MMT.xlsx'
#  'IMPULSE11MANU605_SCARAB_HERO_MMT(1).xlsx'
#  'IMPULSE11MANU605_SCARAB_HEROES TAPER_MMT.xlsx'
#  'IMPULSE10MAN604 HEROES AMMONITE.xlsx'
#  'LAMOSA64MANU568 Bulletproofs_Quite Shade.xlsx'
#  'SAITEX10MANU627 - 12 OZ DENIM - RINSE.xlsx'
#  'SAITEX10MANU627 - 12 OZ DENIM - BROKEN IN.xlsx'
#  'STAR9MANU614_SHARPS TAPER CHARCOAL.xlsx'
#  'IMPULSE11MANU606 HEROES TAPER NAVY 2.xlsx'
#  'SAITEX10MANU627 - 12 OZ DENIM TAPER - CHARCOAL.xlsx'
#  'IMPULSE12MANU606 HEROES GRAPHITE 2.xlsx'
#  'LAMOSA64MANU568 BULLETPROOFS IVY GREEN.xlsx'
#  'IMPULSE11MANU605_SCARAB_HEROES TAPER.xlsx'
#  'FAIRPLAY69MANU633 12 OZ DENIM CHARCOAL BLACK.xlsx'
#  'FAIRPLAY67MANU626 ITALIAN DENIM 7YEARS.xlsx'
#  'FAIRPLAY70MANU644 ITALIAN DENIM HEROES RINSE.xlsx'
#  'FAIRPLAY69MANU633 HEMP BROKEN IN.xlsx'
#  'FAIRPLAY69MANU633 12 OZ TAPER INDIGO.xlsx'
#  'FAIRPLAY67MANU626 ITALIAN DENIM 5YEARS.xlsx'
#  'FAIRPLAY69MANU633 HEMP RINSE INDIGO.xlsx'
#  'FAIRPLAY65MANU591 TRAVEL DENIM BROKEN IN.xlsx'
#  'FAIRPLAY68MANU632 TRAVEL DENIM RINSE.xlsx'
#  'SAITEX10MANU627 - 12 OZ DENIM - CHARCOAL.xlsx'
#  'KAYNAK12MANU638 HEROES HARVEST GOLD.xlsx'
#  'KAYNAK12MANU638 HEROES ICEBERG (QUARRY).xlsx'
#  'KAYNAK12MANU638 HEROES AMMONITE.xlsx'
#  'KAYNAK 10232150763_MMT SHEET1.xlsx'
#  'KAYNAK 10232150763_MMT SHEET 2.xlsx'
#  'KAYNAK HEROES Taper Navy BV 16.08.xlsx'
#  'KAYNAK HEROES reg OliveBV 16.08.xlsx' 'KAYNAK HEROES TAPER BV.xlsx'
#  'KAYNAK HEROES Taper Olive BV 16.08.xlsx'
#  'KAYNAK HEROES Reg Ammonite BV_16.08.xlsx' 'KAYNAK HEROES BV.xlsx'
#  'PTR24.00009_RESPOKE_VALERIUS_2024_01_10_VALERIUS67MANU670_TSHIRT_INSIGNIABLUE.xlsx'
#  'PTR24.0004_Respoke_Lamosa_2024_01_05_Fives_Dark Navy_LAMOSA90MANU675_IR .xlsx'
#  'LKRWT00007514-Respoke-STAR14MANU668-NAVY-StylePLEATE FRONT WIDE LEG.xlsx'
#  'PTR24.00003.4101_RESPOKE_LAMOSA_05.01.2023_FIVES_LAUREL WREATH_LAMOSA80MANU674_ QC.xlsx'
#  'LKRWT00007517-Respoke-STAR13MANU654-LAUREL WREATH-StyleSHARP SHORTS.xlsx'
#  'LKRWT00007512-Respoke-STAR14MANU668-NAVY-StyleELASTICATED WAIST.xlsx'
#  'LKRWT00007494-Respoke-STAR11MANU652-SEPIA TINT-StyleSHARP SHORTS.xlsx'
#  'FRI Report - 40336409-06 - Respoke Limited - PO#TAL21MANU661 - Style#Summer SharpsCOTTON LIGHTWEIGHTS - Ashley Blue - 27 Dec 2023.xlsx'
#  'LKRWT00007513-Respoke-STAR14MANU668-ARGAN OIL-StyleELASTICATED WAIST.xlsx'
#  'LKRWT00007516-Respoke-STAR14MANU668-OLIVE-StylePLEATE FRONT WIDE LEG.xlsx'
#  'LKRWT00007495-Respoke-STAR11MANU652-DARK NAVY-StyleSHARP SHORTS.xlsx'
#  'LKRWT00007515-Respoke-STAR14MANU668-KHAKI-StylePLEATE FRONT WIDE LEG.xlsx'
#  'PTR24.00010_RESPOKE_VALERIUS_2024_01_10_VALERIUS67MANU670_TSHIRT_PERISCOPEECRU.xlsx'
#  'FRI Report - 40336409-03-R1 - Respoke Limited - PO#TAL21MANU661 - Style#Summer SharpsCOTTON LIGHTWEIGHTS - Evening Sand - 27 Dec 2023.xlsx'
#  'KAYNAK16MANU676 INFINITY HEROES.xlsx'
#  'KAYNAK16MANU676 HEROES SOLADITE BLUE.xlsx'
#  'FRI Report - 40336409-02- Respoke Limited - PO#TAL21MANU661 - Style#Summer SharpsCOTTON LIGHTWEIGHTS - Stone - 27 Dec 2023.xlsx'
#  'FRI Report - 40336409-03 - Respoke Limited - PO#TAL21MANU661 - Style#Summer SharpsCOTTON LIGHTWEIGHTS - Evening Sand - 27 Dec 2023.xlsx'
#  'LKRWT00007464-Respoke-STAR13MANU654-DARK NAVY-StyleSHARPS SHORTS.xlsx'
#  'LKRWT00007466-Respoke-STAR13MANU654-FLINTSTONE-StyleSHARP SHORTS.xlsx'
#  '2023_11_27_M312 Grey_RITEDU22MANU659_IR.xlsx'
#  'FRI Report - 40336409-04 - Respoke Limited - PO#TAL21MANU661 - Style#Summer SharpsCOTTON LIGHTWEIGHTS - Laurel Wreath - 27 Dec 2023.xlsx'
#  'LKRWT00007465-Respoke-STAR13MANU654-KHAKI-StyleSHARP SHORTS.xlsx'
#  'FRI Report - 40336409-05 - Respoke Limited - PO#TAL21MANU661 - Style#Summer SharpsCOTTON LIGHTWEIGHTS - Vintage Indigo - 27 Dec 2023.xlsx'
#  'RITEDU22MANU659_IR_CHAMBRAY.xlsx'
#  'FRI Report - 40336409-07 - Respoke Limited - PO#TAL21MANU661 - Style#Summer SharpsCOTTON LIGHTWEIGHTS - Lantana - 27 Dec 2023.xlsx'
#  'KAYNAK16MANU676 HEROES GRAPHITE.xlsx'
#  '2023_11_27_RITEDU22MANU659 DARK_CHAMBRAY.xlsx'
#  'FRI Report - 40341070-04 - Respoke Limited - PO#SAITEX14MANU655 - Style#12 OZ DENIM - CHARCOAL - 24 Jan 2024.xlsx'
#  'FRI Report - 40341070-03 - Respoke Limited - PO#SAITEX14MANU655 - Style#12 OZ DENIM - OLIVE - 24 Jan 2024.xlsx'
#  'FRI Report - 40341070-02 - Respoke Limited - PO#SAITEX14MANU655 - Style#12 OZ DENIM - ECRU - 24 Jan 2024.xlsx'
#  'FRI Report - 40341070-01 - Respoke Limited - PO#SAITEX14MANU655 - Style#12 OZ DENIM - STAY BLACK  - 24 Jan 2024.xlsx'
#  'FRI Report - 40341070-05 - Respoke Limited - PO#SAITEX15MANU677 - Style#12 OZ DENIM - RINSE  - 25 Jan 2024.xlsx'
#  'FRI Report - 40341070-07 - Respoke Limited - PO#SAITEX14MANU655 - Style#12 OZ DENIM - KHAKI  - 25 Jan 2024.xlsx'
#  'FRI Report - 40341070-08 - Respoke Limited - PO#SAITEX14MANU655 - Style#12 OZ DENIM - BLACK - 25 Jan 2024.xlsx'
#  'PTR24.00071_Respoke_Lamosa_2024_02_01_Fives_Riviera_LAMOSA90MANU675_IR.xlsx'
#  'PTR24.00072.4101_RESPOKE_LAMOSA_01.02.2024_FIVES_AMMONITE_LAMOSA90MANU675_ QC.xlsx'
#  'KAYNAK17MANU682-HEROES-BLACK.xlsx'
#  'KAYNAK17MANU682-HEROES-MARS-(BRICK RED.xlsx'
#  'KAYNAK17MANU682 - HEROES - DUSTY ROSE.xlsx'
#  'KAYNAK17MANU682 - OLIVE - HEROES.xlsx']
# folder_name ['QC_files_AW23' 'QC_files_SS24']
# file_id ['FIRST | KAYNAK13MANU640 | HEROES | BLACK  (BLACK ONYX)'
#  'FIRST | KAYNAK13MANU640 | HEROES TAPER | BLACK  (BLACK ONYX)'
#  'FIRST | KAYNAK13MANU640 | HEROES | FLINTSTONE (INFINITY)'
#  'FIRST | KAYNAK13MANU640 | HEROES TAPER | FLINTSTONE (INFINITY)'
#  'FIRST | KAYNAK13MANU640 | HEROES | ICEBERG (QUARRY)'
#  'FIRST | KAYNAK13MANU640 | HEROES TAPER | MAROON (RHUBARB)'
#  'FIRST | KAYNAK13MANU640 | HEROES | SAGE (ICEBERG GREEN)'
#  'FIRST | KAYNAK13MANU640 | HEROES TAPER | SAGE (ICEBERG GREEN)'
#  'FIRST | KAYNAK14MANU642 | HEROES TAPER | MEDIEVAL BLUE'
#  'FIRST | KAYNAK14MANU642 | HEROES | MEDIEVAL BLUE'
#  'FIRST | KAYNAK13MANU640 | HEROES | MAROON (RHUBARB)'
#  'FIRST | KAYNAK13MANU640 | HEROES TAPER | KHAKI'
#  'FIRST | KAYNAK13MANU640 | HEROES | KHAKI'
#  ' | HKS2MANU684 | CASHMERE HALF ZIP | NAVY'
#  'FIRST | IMPULSE13MANU607 | WINTER HEROES | BITTER CHOCOLATE'
#  ' | VIPALTEX1MANU648 | HEAVY T-SHIRT | WHITE'
#  ' | VIPALTEX1MANU648 | HEAVY T-SHIRT | NAVY'
#  ' | HKS2MANU684 | CASHMERE HALF ZIP | GREY MARL'
#  'nan | ECOVEST2MANU700 | BOXERS | NAVY'
#  'nan | LAMOSA69MANU630 | CORD FIVES | NAVY'
#  ' | VIPALTEX1MANU648 | HEAVY T-SHIRT | SCARAB'
#  'FIRST | nan | MOLESKIN FIVES | nan'
#  'FIRST | ECOVEST2MANU700 | BOXERS | NAVY'
#  ' | HKS2MANU684 | CASHMERE HALF ZIP | OATMEAL'
#  'FIRST | ECOVEST1MANU595 | BOXERS | NAVY'
#  'FIRST | LAMOSA69MANU630 | CORD FIVES | GRISAILLE'
#  'FIRST | ECOVESTT1MANU595 | BOXERS | BLACK'
#  'FIRST | KAYNAK15MANU658 | HEROES | CARAMEL (CARAMEL CAFÉ)'
#  'FIRST | ECOVEST1MANU595 | BOXERS | BLACK'
#  'FIRST | KAYNAK15MANU658 | HEROES | FOREST (SCARAB)'
#  'nan | LAMOSA70MANU637 | CORD FIVES | IVY GREEN'
#  'FIRST | LAMOSA69MANU630 | CORD FIVES | FAWN'
#  'FIRST | LAMOSA69MANU630 | CORD FIVES | FEATHER GREY'
#  'FIRST | SARTIUS22MANU643 | WINTER SMARTS | BLUE HERRINGBONE'
#  'FIRST | LAMOSA67MANU617 | MOLESKIN FIVES | BRICK RED'
#  'FIRST | SARTIUS22MANU643 | SANTA PANT | RED'
#  'FIRST | IMPULSE15MANU629 | HEROES | CROWN BLUE'
#  'FIRST | IMPULSE13MANU607 | WINTER HEROES | DARK NAVY'
#  'FIRST | IMPULSE15MANU629 | HEROES | INFINITY'
#  'FIRST | IMPULSE15MANU629 | HEROES TAPER | GRAPHITE'
#  'FIRST | IMPULSE13MANU607 | WINTER HEROES | DEEP FOREST'
#  'FIRST | IMPULSE13MANU607 | WINTER HEROES | BEECH'
#  'FIRST | TAL17MANU636 | SHARPS | NOCTURNE (VINTAGE INDIGO)'
#  'FIRST | TAL17MANU636 | SHARPS | THUNDER (STORMY WEATHER)'
#  ' | VALERIUS62MANU641 | LONG SLEEVE T-SHIRT | QUARRY'
#  ' | VALERIUS62MANU641 | LONG SLEEVE T-SHIRT | NAVY'
#  ' | VALERIUS62MANU641 | LONG SLEEVE T-SHIRT | WHITE'
#  'FIRST | IMPULSE15MANU629 | HEROES TAPER | INFINITY'
#  'FIRST | nan | HEROES TAPER | ICEBERG (QUARRY)'
#  'FIRST | STAR10MANU625 | CASHMERE SHARPS | BLACK'
#  'FIRST | STAR10MANU625 | CORD SHARPS | NAVY'
#  'FIRST | nan | HEROES TAPER | OLIVE'
#  'FIRST | IMPULSE15MANU629 | HEROES TAPER | OLIVE'
#  'FIRST | nan | HEROES | OLIVE'
#  'FIRST | LAMOSA67MANU617 | MOLESKIN FIVES | COFFEE BEAN'
#  'FIRST | STAR10MANU625 | CASHMERE SHARPS | NAVY'
#  'FIRST | STAR10MANU625 | CORD SHARPS | FAWN'
#  'FIRST | nan | HEROES TAPER | NAVY'
#  'FIRST | IMPULSE15MANU629 | HEROES | NAVY'
#  'FIRST | nan | HEROES | HARVEST GOLD' 'FIRST | nan | HEROES TAPER | ONYX'
#  'FIRST | STAR10MANU625 | VELVET SHARPS | NAVY'
#  'FIRST | IMPULSE15MANU629 | HEROES | OLIVE'
#  ' | RUTEDU20MANU620 | CORD SHIRT | BIRCH'
#  'FIRST | nan | HEROES TAPER | SMOKED NAVY (CROWN BLUE)'
#  'FIRST | nan | HEROES | ICEBERG (QUARRY)'
#  'FIRST | nan | HEROES | AMMONITE'
#  'FIRST | STAR10MANU625 | VELVET SHARPS | MULBERRY (TAWNY)'
#  'FIRST | LAMOSA68MANU618 | CORD FIVES | CARAMEL CAFÉ'
#  'FIRST | LAMOSA67MANU617 | MOLESKIN FIVES | DEEP SPACE'
#  'FIRST | LAMOSA67MANU617 | MOLESKIN FIVES | IVY GREEN'
#  ' | RUTEDU20MANU620 | CORD SHIRT | SCARAB'
#  ' | RITEDU20MANU620 | CORD SHIRT | DARK NAVY'
#  ' | RUTEDU20MANU620 | CORD SHIRT | MAUVE SHADOWS'
#  'FIRST | nan | HEROES TAPER | nan'
#  'nan | LAMOSA67MANU617 | MOLESKIN FIVES | HARVEST GOLD'
#  'FIRST | nan | HEROES | nan'
#  ' | VALERIUS65MANU647 | T-SHIRT | GREEN GABLES'
#  'nan | LAMOSA68MANU618 | CORD FIVES | IVY GREEN'
#  ' | RITEDU19MANU619 | OXFORD SHIRT | MARRON CHECK'
#  ' | RITEDU20MANU620 | CORD SHIRT | TAWNY PORT'
#  ' | RUTEDU19MANU619 | OXFORD SHIRT | STONE'
#  ' | RUTEDU19MANU619 | OXFORD SHIRT | OLIVE'
#  ' | VALERIUS65MANU647 | T-SHIRT | RHUBARB'
#  'FIRST | FAIRPLAY67MANU626 | ITALIAN DENIM 7 YEAR WASH | 7YEAR'
#  'FIRST | SAITEX13MANU649 | HEROES | DIJON'
#  'FIRST | SAITEX13MANU649 | HEROES TAPER | COFFEE BEAN'
#  'FIRST | SAITEX13MANU649 | HEROES TAPER | DIJON'
#  'FIRST | SAITEX13MANU649 | HEROES | COFFEE BEAN'
#  'FIRST | SAITEX12MANU639 | 12 OZ DENIM BROKEN IN/CHARCOAL/KHAKI/OLIVE | BROKEN IN'
#  'FIRST | STAR9MANU614 | SHARPS TAPER | CHARCOAL'
#  'FIRST | STAR9MANU614 | SHARPS TAPER | DARK NAVY'
#  'FIRST | STAR9MANU614 | SHARPS | CHARCOAL'
#  'FIRST | STAR9MANU614 | SHARPS | DARK NAVY'
#  'FIRST | SAITEX11MANU628 | 12 OZ DENIM TAPER RINSE/BLACK | BLACK'
#  'FIRST | SAITEX11MANU628 | 12 OZ DENIM RINSE/BLACK | BLACK'
#  'FIRST | SAITEX11MANU628 | 12 OZ DENIM TAPER RINSE/BLACK | RINSE'
#  'FIRST | SAITEX11MANU628 | 12 OZ DENIM RINSE/BLACK | RINSE'
#  'FIRST | ECOVEST2MANU700 | BOXERS | SCARAB'
#  'FIRST | ECOVEST2MANU700 | BOXERS | FOREST'
#  'FIRST | IMPULSE1MAN604 | HEROES TAPER | AMMONITE'
#  'FIRST | IMPULSE11MANU605 | HEROES TAPER | INFINITY'
#  'FIRST | IMPULSE12MANU606 | HEROES | NAVY'
#  ' | RITEDU18MANU608 | OXFORD SHIRT | GREY MARL'
#  'FIRST | IMPULSE11MANU605 | HEROES TAPER | OLIVE'
#  'FIRST | IMPULSE11MANU605 | HEROES | OLIVE'
#  ' | RUTEDU18MANU608 | OXFORD SHIRT | DARK CHAMBRAY'
#  ' | RUTEDU18MANU608 | OXFORD SHIRT | WHITE'
#  'FIRST | IMPULSE11MANU605 | HEROES | INFINITY'
#  ' | RITEDU18MANU608 | OXFORD SHIRT | SKY'
#  'FIRST | IMPULSE12MANU606 | HEROES TAPER | GRAPHITE'
#  'nan | LAMOSA64MANU568 | NANTUCKET FIVES | SKY CAPTAIN'
#  'FIRST | SAITEX10MANU627 | 12 OZ DENIM BROKEN IN/CHARCOAL | BROKEN IN'
#  'FIRST | IMPULSE12MANU606 | HEROES | GRAPHITE'
#  'FIRST | IMPULSE11MANU606 | HEROES TAPER | NAVY'
#  'FIRST | IMPULSE10MANU604 | HEROES | AMMONOITE'
#  'FIRST | SAITEX11MANU628 | 12 OZ DENIM BROKEN IN/CHARCOAL | BROKEN IN'
#  'FIRST | IMPULSE10MANU604 | HEROES TAPER | AMMONITE'
#  'FIRST | IMPULSE10MAN604 | HEROES TAPER | AMMONITE'
#  'FIRST | LAMOSA64MANU568 | BULLETPROOFS | BLACK ONYX'
#  'FIRST | SAITEX10MANU627 | 12 OZ DENIM TAPER RINSE/BLACK | RINSE'
#  'nan | LAMOSA64MANU568 | NANTUCKET FIVES | LEAD'
#  'FIRST | SAITEX9MANU610 | STAY BLACK DENIM | nan'
#  'nan | LAMOSA64MANU568 | NANTUCKET FIVES | AQUA GREY'
#  'FIRST | IMPULSE11MANU605 | HEROES | SCARAB'
#  'FIRST | SAITEX10MANU627 | 12 OZ DENIM TAPER BROKEN IN/CHARCOAL | BROKEN IN'
#  'FIRST | IMPULSE11MANU605 | HEROES TAPER | SCARAB'
#  'FIRST | IMPULSE10MAN604 | HEROES | AMMONOITE'
#  'FIRST | LAMOSA64MANU568 | BULLETPROOFS | QUIET SHADE'
#  'FIRST | SAITEX10MANU627 | 12 OZ DENIM RINSE/BLACK | RINSE'
#  'FIRST | SAITEX10MANU627 | 12 OZ DENIM TAPER BROKEN IN/CHARCOAL | CHARCOAL'
#  'FIRST | LAMOSA64MANU568 | BULLETPROOFS | IVY GREEN'
#  ' | FAIRPLAY69MANU633 | 12 OZ DENIM BROKEN IN/CHARCOAL | BLACK'
#  'FIRST | FAIRPLAY70MANU644 | HEROES | ITALIAN DENIM HEROES RINSE WASH'
#  ' | FAIRPLAY69MANU633 | HEMP DENIM BROKEN IN | INDIGO'
#  ' | FAIRPLAY69MANU633 | 12 OZ DENIM TAPER BROKEN IN/CHARCOAL | INDIGO'
#  'FIRST | FAIRPLAY67MANU626 | ITALIAN DENIM 7 YEAR WASH | 5YEAR'
#  ' | FAIRPLAY69MANU633 | HEMP DENIM RINSE | INDINGO'
#  ' | FAIRPLAY65MANU591 | TRAVEL DENIM BROKEN IN/CHARCOAL | BROKEN IN'
#  ' | FAIRPLAY68MANU632 | TRAVEL DENIM RINSE/BLACK | RINSE'
#  'FIRST | SAITEX10MANU627 | 12 OZ DENIM BROKEN IN/CHARCOAL | CHARCOAL'
#  'FIRST | KAYNAK12MANU638 | HEROES | HARVEST GOLD'
#  'FIRST | KAYNAK12MANU638 | HEROES | ICEBERG (QUARRY)'
#  'FIRST | KAYNAK12MANU638 | HEROES | AMMONITE'
#  ' | VALERIUS67MANU670 | BRETON SS T SHIRT | INSIGNIA/BLUE'
#  'FIRST | LAMOSA90MANU675 | FIVES | DARK NAVY'
#  'FIRST | STAR14MANU668 | PLEATE FRONT WIDE LEG | NAVY'
#  'FIRST | LAMOSA80MANU670 | FIVES | LAUREL'
#  'FIRST | STAR13MANU654 | SHARP SHORTS | LAUREL WREATH'
#  'FIRST | STAR14MANU668 | ELASTICATED WAIST | NAVY'
#  'FIRST | STAR11MANU652 | SHARP SHORTS | SEPIA TINT'
#  'FIRST | TAL21MANU661 | COTTON LIGHTWEIGHTS | ASHLEY BLUE'
#  'FIRST | STAR14MANU668 | ELASTICATED WAIST | ARGAN OIL'
#  'FIRST | STAR14MANU668 | PLEATE FRONT WIDE LEG | OLIVE'
#  'FIRST | STAR11MANU652 | SHARP SHORTS | DARK NAVY'
#  'FIRST | STAR14MANU668 | PLEATE FRONT WIDE LEG | KHAKI'
#  ' | VALERIUS67MANU670 | BRETON SS T SHIRT | PERISCOPE/ECRU'
#  'FIRST | TAL21MANU661 | COTTON LIGHTWEIGHTS | EVENING SAND'
#  'FIRST | KAYNAK16MANU676 | HEROES | INFINITY'
#  'FIRST | KAYNAK16MANU676 | HEROES | SOLADITE BLUE'
#  'FIRST | TAL21MANU661 | COTTON LIGHTWEIGHTS | STONE'
#  'FIRST | STAR13MANU654 | SHARP SHORTS | DARK NAVY'
#  'FIRST | STAR13MANU654 | SHARP SHORTS | FLINTSTONE'
#  ' | RITEDU22MANU659 | OXFORD SHIRT | GREY'
#  'FIRST | TAL21MANU661 | COTTON LIGHTWEIGHTS | LAUREL WREATH'
#  'FIRST | STAR13MANU654 | SHARP SHORTS | KHAKI'
#  'FIRST | TAL21MANU661 | COTTON LIGHTWEIGHTS | VINTAGE INDIGO'
#  ' | RITEDU22MANU659 | OXFORD SHIRT | CHAMBRAY'
#  'FIRST | TAL21MANU661 | COTTON LIGHTWEIGHTS | LANTANA'
#  'FIRST | KAYNAK16MANU676 | HEROES | GRAPHITE'
#  ' | RITEDU22MANU659 | OXFORD SHIRT | DARK CHAMBRAY'
#  'FIRST | SAITEX14MANU655 | 12 OZ DENIM BROKEN IN/CHARCOAL/KHAKI/OLIVE | CHARCOAL'
#  'FIRST | SAITEX14MANU655 | 12 OZ DENIM BROKEN IN/CHARCOAL/KHAKI/OLIVE | OLIVE'
#  'FIRST | SAITEX14MANU655 | 12 OZ DENIM BROKEN IN/CHARCOAL/KHAKI/OLIVE | ECRU'
#  'FIRST | SAITEX14MANU655 | 12 OZ DENIM RINSE/BLACK | STAY BLACK'
#  'FIRST | SAITEX15MANU677 | 12 OZ DENIM RINSE/BLACK | RINSE'
#  'FIRST | SAITEX14MANU655 | 12 OZ DENIM BROKEN IN/CHARCOAL/KHAKI/OLIVE | KHAKI'
#  'FIRST | SAITEX14MANU655 | 12 OZ DENIM RINSE/BLACK | BLACK'
#  'FIRST | LAMOSA90MANU675 | FIVES | RIVIERA'
#  'FIRST | LAMOSA90MANU675 | FIVES | AMMONITE'
#  'FIRST | KAYNAK17MANU682 | HEROES | BLACK'
#  'FIRST | KAYNAK17MANU682 | HEROES | MARS (BRICK RED)'
#  'FIRST | KAYNAK17MANU682 | HEROES | DUSTY ROSE'
#  'FIRST | KAYNAK17MANU682 | HEROES | OLİVE']
# batch_id ['KAYNAK13MANU640 | HEROES | BLACK  (BLACK ONYX)'
#  'KAYNAK13MANU640 | HEROES TAPER | BLACK  (BLACK ONYX)'
#  'KAYNAK13MANU640 | HEROES | FLINTSTONE (INFINITY)'
#  'KAYNAK13MANU640 | HEROES TAPER | FLINTSTONE (INFINITY)'
#  'KAYNAK13MANU640 | HEROES | ICEBERG (QUARRY)'
#  'KAYNAK13MANU640 | HEROES TAPER | MAROON (RHUBARB)'
#  'KAYNAK13MANU640 | HEROES | SAGE (ICEBERG GREEN)'
#  'KAYNAK13MANU640 | HEROES TAPER | SAGE (ICEBERG GREEN)'
#  'KAYNAK14MANU642 | HEROES TAPER | MEDIEVAL BLUE'
#  'KAYNAK14MANU642 | HEROES | MEDIEVAL BLUE'
#  'KAYNAK13MANU640 | HEROES | MAROON (RHUBARB)'
#  'KAYNAK13MANU640 | HEROES TAPER | KHAKI'
#  'KAYNAK13MANU640 | HEROES | KHAKI'
#  'HKS2MANU684 | CASHMERE HALF ZIP | NAVY'
#  'IMPULSE13MANU607 | WINTER HEROES | BITTER CHOCOLATE'
#  'VIPALTEX1MANU648 | HEAVY T-SHIRT | WHITE'
#  'VIPALTEX1MANU648 | HEAVY T-SHIRT | NAVY'
#  'HKS2MANU684 | CASHMERE HALF ZIP | GREY MARL'
#  'ECOVEST2MANU700 | BOXERS | NAVY' 'LAMOSA69MANU630 | CORD FIVES | NAVY'
#  'VIPALTEX1MANU648 | HEAVY T-SHIRT | SCARAB' 'nan | MOLESKIN FIVES | nan'
#  'HKS2MANU684 | CASHMERE HALF ZIP | OATMEAL'
#  'ECOVEST1MANU595 | BOXERS | NAVY'
#  'LAMOSA69MANU630 | CORD FIVES | GRISAILLE'
#  'ECOVESTT1MANU595 | BOXERS | BLACK'
#  'KAYNAK15MANU658 | HEROES | CARAMEL (CARAMEL CAFÉ)'
#  'ECOVEST1MANU595 | BOXERS | BLACK'
#  'KAYNAK15MANU658 | HEROES | FOREST (SCARAB)'
#  'LAMOSA70MANU637 | CORD FIVES | IVY GREEN'
#  'LAMOSA69MANU630 | CORD FIVES | FAWN'
#  'LAMOSA69MANU630 | CORD FIVES | FEATHER GREY'
#  'SARTIUS22MANU643 | WINTER SMARTS | BLUE HERRINGBONE'
#  'LAMOSA67MANU617 | MOLESKIN FIVES | BRICK RED'
#  'SARTIUS22MANU643 | SANTA PANT | RED'
#  'IMPULSE15MANU629 | HEROES | CROWN BLUE'
#  'IMPULSE13MANU607 | WINTER HEROES | DARK NAVY'
#  'IMPULSE15MANU629 | HEROES | INFINITY'
#  'IMPULSE15MANU629 | HEROES TAPER | GRAPHITE'
#  'IMPULSE13MANU607 | WINTER HEROES | DEEP FOREST'
#  'IMPULSE13MANU607 | WINTER HEROES | BEECH'
#  'TAL17MANU636 | SHARPS | NOCTURNE (VINTAGE INDIGO)'
#  'TAL17MANU636 | SHARPS | THUNDER (STORMY WEATHER)'
#  'VALERIUS62MANU641 | LONG SLEEVE T-SHIRT | QUARRY'
#  'VALERIUS62MANU641 | LONG SLEEVE T-SHIRT | NAVY'
#  'VALERIUS62MANU641 | LONG SLEEVE T-SHIRT | WHITE'
#  'IMPULSE15MANU629 | HEROES TAPER | INFINITY'
#  'nan | HEROES TAPER | ICEBERG (QUARRY)'
#  'STAR10MANU625 | CASHMERE SHARPS | BLACK'
#  'STAR10MANU625 | CORD SHARPS | NAVY' 'nan | HEROES TAPER | OLIVE'
#  'IMPULSE15MANU629 | HEROES TAPER | OLIVE' 'nan | HEROES | OLIVE'
#  'LAMOSA67MANU617 | MOLESKIN FIVES | COFFEE BEAN'
#  'STAR10MANU625 | CASHMERE SHARPS | NAVY'
#  'STAR10MANU625 | CORD SHARPS | FAWN' 'nan | HEROES TAPER | NAVY'
#  'IMPULSE15MANU629 | HEROES | NAVY' 'nan | HEROES | HARVEST GOLD'
#  'nan | HEROES TAPER | ONYX' 'STAR10MANU625 | VELVET SHARPS | NAVY'
#  'IMPULSE15MANU629 | HEROES | OLIVE'
#  'RUTEDU20MANU620 | CORD SHIRT | BIRCH'
#  'nan | HEROES TAPER | SMOKED NAVY (CROWN BLUE)'
#  'nan | HEROES | ICEBERG (QUARRY)' 'nan | HEROES | AMMONITE'
#  'STAR10MANU625 | VELVET SHARPS | MULBERRY (TAWNY)'
#  'LAMOSA68MANU618 | CORD FIVES | CARAMEL CAFÉ'
#  'LAMOSA67MANU617 | MOLESKIN FIVES | DEEP SPACE'
#  'LAMOSA67MANU617 | MOLESKIN FIVES | IVY GREEN'
#  'RUTEDU20MANU620 | CORD SHIRT | SCARAB'
#  'RITEDU20MANU620 | CORD SHIRT | DARK NAVY'
#  'RUTEDU20MANU620 | CORD SHIRT | MAUVE SHADOWS' 'nan | HEROES TAPER | nan'
#  'LAMOSA67MANU617 | MOLESKIN FIVES | HARVEST GOLD' 'nan | HEROES | nan'
#  'VALERIUS65MANU647 | T-SHIRT | GREEN GABLES'
#  'LAMOSA68MANU618 | CORD FIVES | IVY GREEN'
#  'RITEDU19MANU619 | OXFORD SHIRT | MARRON CHECK'
#  'RITEDU20MANU620 | CORD SHIRT | TAWNY PORT'
#  'RUTEDU19MANU619 | OXFORD SHIRT | STONE'
#  'RUTEDU19MANU619 | OXFORD SHIRT | OLIVE'
#  'VALERIUS65MANU647 | T-SHIRT | RHUBARB'
#  'FAIRPLAY67MANU626 | ITALIAN DENIM 7 YEAR WASH | 7YEAR'
#  'SAITEX13MANU649 | HEROES | DIJON'
#  'SAITEX13MANU649 | HEROES TAPER | COFFEE BEAN'
#  'SAITEX13MANU649 | HEROES TAPER | DIJON'
#  'SAITEX13MANU649 | HEROES | COFFEE BEAN'
#  'SAITEX12MANU639 | 12 OZ DENIM BROKEN IN/CHARCOAL/KHAKI/OLIVE | BROKEN IN'
#  'STAR9MANU614 | SHARPS TAPER | CHARCOAL'
#  'STAR9MANU614 | SHARPS TAPER | DARK NAVY'
#  'STAR9MANU614 | SHARPS | CHARCOAL' 'STAR9MANU614 | SHARPS | DARK NAVY'
#  'SAITEX11MANU628 | 12 OZ DENIM TAPER RINSE/BLACK | BLACK'
#  'SAITEX11MANU628 | 12 OZ DENIM RINSE/BLACK | BLACK'
#  'SAITEX11MANU628 | 12 OZ DENIM TAPER RINSE/BLACK | RINSE'
#  'SAITEX11MANU628 | 12 OZ DENIM RINSE/BLACK | RINSE'
#  'ECOVEST2MANU700 | BOXERS | SCARAB' 'ECOVEST2MANU700 | BOXERS | FOREST'
#  'IMPULSE1MAN604 | HEROES TAPER | AMMONITE'
#  'IMPULSE11MANU605 | HEROES TAPER | INFINITY'
#  'IMPULSE12MANU606 | HEROES | NAVY'
#  'RITEDU18MANU608 | OXFORD SHIRT | GREY MARL'
#  'IMPULSE11MANU605 | HEROES TAPER | OLIVE'
#  'IMPULSE11MANU605 | HEROES | OLIVE'
#  'RUTEDU18MANU608 | OXFORD SHIRT | DARK CHAMBRAY'
#  'RUTEDU18MANU608 | OXFORD SHIRT | WHITE'
#  'IMPULSE11MANU605 | HEROES | INFINITY'
#  'RITEDU18MANU608 | OXFORD SHIRT | SKY'
#  'IMPULSE12MANU606 | HEROES TAPER | GRAPHITE'
#  'LAMOSA64MANU568 | NANTUCKET FIVES | SKY CAPTAIN'
#  'SAITEX10MANU627 | 12 OZ DENIM BROKEN IN/CHARCOAL | BROKEN IN'
#  'IMPULSE12MANU606 | HEROES | GRAPHITE'
#  'IMPULSE11MANU606 | HEROES TAPER | NAVY'
#  'IMPULSE10MANU604 | HEROES | AMMONOITE'
#  'SAITEX11MANU628 | 12 OZ DENIM BROKEN IN/CHARCOAL | BROKEN IN'
#  'IMPULSE10MANU604 | HEROES TAPER | AMMONITE'
#  'IMPULSE10MAN604 | HEROES TAPER | AMMONITE'
#  'LAMOSA64MANU568 | BULLETPROOFS | BLACK ONYX'
#  'SAITEX10MANU627 | 12 OZ DENIM TAPER RINSE/BLACK | RINSE'
#  'LAMOSA64MANU568 | NANTUCKET FIVES | LEAD'
#  'SAITEX9MANU610 | STAY BLACK DENIM | nan'
#  'LAMOSA64MANU568 | NANTUCKET FIVES | AQUA GREY'
#  'IMPULSE11MANU605 | HEROES | SCARAB'
#  'SAITEX10MANU627 | 12 OZ DENIM TAPER BROKEN IN/CHARCOAL | BROKEN IN'
#  'IMPULSE11MANU605 | HEROES TAPER | SCARAB'
#  'IMPULSE10MAN604 | HEROES | AMMONOITE'
#  'LAMOSA64MANU568 | BULLETPROOFS | QUIET SHADE'
#  'SAITEX10MANU627 | 12 OZ DENIM RINSE/BLACK | RINSE'
#  'SAITEX10MANU627 | 12 OZ DENIM TAPER BROKEN IN/CHARCOAL | CHARCOAL'
#  'LAMOSA64MANU568 | BULLETPROOFS | IVY GREEN'
#  'FAIRPLAY69MANU633 | 12 OZ DENIM BROKEN IN/CHARCOAL | BLACK'
#  'FAIRPLAY70MANU644 | HEROES | ITALIAN DENIM HEROES RINSE WASH'
#  'FAIRPLAY69MANU633 | HEMP DENIM BROKEN IN | INDIGO'
#  'FAIRPLAY69MANU633 | 12 OZ DENIM TAPER BROKEN IN/CHARCOAL | INDIGO'
#  'FAIRPLAY67MANU626 | ITALIAN DENIM 7 YEAR WASH | 5YEAR'
#  'FAIRPLAY69MANU633 | HEMP DENIM RINSE | INDINGO'
#  'FAIRPLAY65MANU591 | TRAVEL DENIM BROKEN IN/CHARCOAL | BROKEN IN'
#  'FAIRPLAY68MANU632 | TRAVEL DENIM RINSE/BLACK | RINSE'
#  'SAITEX10MANU627 | 12 OZ DENIM BROKEN IN/CHARCOAL | CHARCOAL'
#  'KAYNAK12MANU638 | HEROES | HARVEST GOLD'
#  'KAYNAK12MANU638 | HEROES | ICEBERG (QUARRY)'
#  'KAYNAK12MANU638 | HEROES | AMMONITE'
#  'VALERIUS67MANU670 | BRETON SS T SHIRT | INSIGNIA/BLUE'
#  'LAMOSA90MANU675 | FIVES | DARK NAVY'
#  'STAR14MANU668 | PLEATE FRONT WIDE LEG | NAVY'
#  'LAMOSA80MANU670 | FIVES | LAUREL'
#  'STAR13MANU654 | SHARP SHORTS | LAUREL WREATH'
#  'STAR14MANU668 | ELASTICATED WAIST | NAVY'
#  'STAR11MANU652 | SHARP SHORTS | SEPIA TINT'
#  'TAL21MANU661 | COTTON LIGHTWEIGHTS | ASHLEY BLUE'
#  'STAR14MANU668 | ELASTICATED WAIST | ARGAN OIL'
#  'STAR14MANU668 | PLEATE FRONT WIDE LEG | OLIVE'
#  'STAR11MANU652 | SHARP SHORTS | DARK NAVY'
#  'STAR14MANU668 | PLEATE FRONT WIDE LEG | KHAKI'
#  'VALERIUS67MANU670 | BRETON SS T SHIRT | PERISCOPE/ECRU'
#  'TAL21MANU661 | COTTON LIGHTWEIGHTS | EVENING SAND'
#  'KAYNAK16MANU676 | HEROES | INFINITY'
#  'KAYNAK16MANU676 | HEROES | SOLADITE BLUE'
#  'TAL21MANU661 | COTTON LIGHTWEIGHTS | STONE'
#  'STAR13MANU654 | SHARP SHORTS | DARK NAVY'
#  'STAR13MANU654 | SHARP SHORTS | FLINTSTONE'
#  'RITEDU22MANU659 | OXFORD SHIRT | GREY'
#  'TAL21MANU661 | COTTON LIGHTWEIGHTS | LAUREL WREATH'
#  'STAR13MANU654 | SHARP SHORTS | KHAKI'
#  'TAL21MANU661 | COTTON LIGHTWEIGHTS | VINTAGE INDIGO'
#  'RITEDU22MANU659 | OXFORD SHIRT | CHAMBRAY'
#  'TAL21MANU661 | COTTON LIGHTWEIGHTS | LANTANA'
#  'KAYNAK16MANU676 | HEROES | GRAPHITE'
#  'RITEDU22MANU659 | OXFORD SHIRT | DARK CHAMBRAY'
#  'SAITEX14MANU655 | 12 OZ DENIM BROKEN IN/CHARCOAL/KHAKI/OLIVE | CHARCOAL'
#  'SAITEX14MANU655 | 12 OZ DENIM BROKEN IN/CHARCOAL/KHAKI/OLIVE | OLIVE'
#  'SAITEX14MANU655 | 12 OZ DENIM BROKEN IN/CHARCOAL/KHAKI/OLIVE | ECRU'
#  'SAITEX14MANU655 | 12 OZ DENIM RINSE/BLACK | STAY BLACK'
#  'SAITEX15MANU677 | 12 OZ DENIM RINSE/BLACK | RINSE'
#  'SAITEX14MANU655 | 12 OZ DENIM BROKEN IN/CHARCOAL/KHAKI/OLIVE | KHAKI'
#  'SAITEX14MANU655 | 12 OZ DENIM RINSE/BLACK | BLACK'
#  'LAMOSA90MANU675 | FIVES | RIVIERA' 'LAMOSA90MANU675 | FIVES | AMMONITE'
#  'KAYNAK17MANU682 | HEROES | BLACK'
#  'KAYNAK17MANU682 | HEROES | MARS (BRICK RED)'
#  'KAYNAK17MANU682 | HEROES | DUSTY ROSE'
#  'KAYNAK17MANU682 | HEROES | OLİVE']

# %%
# # QC Units: Fields in QC Units tables
# qc_units_tops_fields = [
#                             'unit_size',
#                             'unit_fit',
#                             'unit_length',
#                             'approved',
#                             'm_chest', 'r_chest',
#                             'm_waist', 'r_waist',
#                             'm_front_length', 'r_front_length',
#                             'm_sleeve_length', 'r_sleeve_length',
#                             'm_muscle', 'r_muscle',
#                             'm_cuff_width', 'r_cuff_width',
#                             'm_neck_circ', 'r_neck_circ'
#                         ]

# qc_units_tops = pd.DataFrame(columns=qc_units_tops_fields)

# qc_units_trousers_fields = [
#                               'unit_size',
#                               'unit_fit',
#                               'unit_length',
#                               'approved',
#                               'm_half_waist', 'r_half_waist',
#                               'm_low_hip', 'r_low_hip',
#                               'm_front_rise', 'r_front_rise',
#                               'm_back_rise', 'r_back_rise',
#                               'm_thigh', 'r_thigh',
#                               'm_knee', 'r_knee',
#                               'm_hem', 'r_hem'
#                           ]

# qc_units_trousers = pd.DataFrame(columns=qc_units_trousers_fields)

# # QC Units: Garment type --> Sheet
# qc_unit_sheets_mapping = {'Tops': 'MEASUREMENTS TOPS',
#                  'Trousers': 'MEASUREMENTS TROUSERS',
#                  'Boxers': 'MEASUREMENTS BOXERS'}
